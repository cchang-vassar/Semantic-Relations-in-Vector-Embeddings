# %% [markdown]
# <a href="https://colab.research.google.com/github/cchang-vassar/Semantic-Relations-in-Vector-Embeddings/blob/main/study2_8_%5Bada003%5D_scifact_autoencoder_gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [ada-003] Autoencoder: Generate Corresponding Embedding

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Imports

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import os
import subprocess
import zipfile
import shutil
import pickle
import tensorflow as tf
import pandas as pd
import numpy as np
from google.colab import userdata
from scipy import spatial
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from plotnine import ggplot, geom_line, aes, ggsave, labs, theme, element_text, guides, guide_legend, scale_color_manual, scale_y_continuous, scale_linetype_manual

# %% [markdown]
# ### OSF Setup

# %%
# !pip install osfclient
# Out:
# Collecting osfclient
#   Downloading osfclient-0.0.5-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from osfclient) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from osfclient) (4.66.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from osfclient) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (2024.2.2)
# Installing collected packages: osfclient
# Successfully installed osfclient-0.0.5

# %%
import osfclient.cli

# %%
from osfclient.api import OSF
from osfclient.models import Project, Storage
from io import BytesIO

# %%
os.environ["OSF_USERNAME"] = userdata.get("OSF_USERNAME")
OSF_USERNAME = os.environ["OSF_USERNAME"]

# %%
os.environ["OSF_PASSWORD"] = userdata.get("OSF_PASSWORD")
OSF_PASSWORD = os.environ["OSF_PASSWORD"]

# %%
os.environ["OSF_TOKEN"] = userdata.get("OSF_TOKEN")
OSF_TOKEN = os.environ["OSF_TOKEN"]

# %%
os.environ["OSF_PROJECT_ID"] = userdata.get("OSF_PROJECT_ID")
OSF_PROJECT_ID = os.environ["OSF_PROJECT_ID"]

# %% [markdown]
# ## Data

# %% [markdown]
# ### Import corpora data from OSF

# %%
# !osf -p sakjg fetch osfstorage/data-dump/ada003-autoencoder/ada_scifact_embeddings_dump.zip
# Out:
# 100% 17.0M/17.0M [00:01<00:00, 8.82Mbytes/s]

# %%
embeddings_file_path = 'ada_scifact_embeddings_dump.zip'
output_folder_path = 'current-data-dump/embeddings-dump'
os.makedirs(output_folder_path, exist_ok=True)

with zipfile.ZipFile(embeddings_file_path, 'r') as zip_ref:
  zip_ref.extractall(output_folder_path)

extracted_files = os.listdir(output_folder_path)
print("Files extracted:", extracted_files)
# Out:
# Files extracted: ['training_pro_argument_embeddings.pkl', 'combined_counter_evidence_embeddings.pkl', 'training_pro_evidence_embeddings.pkl', 'combined_pro_argument_embeddings.pkl', 'test_counter_evidence_embeddings.pkl', 'training_counter_argument_embeddings.pkl', 'test_counter_argument_embeddings.pkl', 'combined_counter_argument_embeddings.pkl', 'combined_pro_evidence_embeddings.pkl', 'test_pro_evidence_embeddings.pkl', 'test_pro_argument_embeddings.pkl', 'training_counter_evidence_embeddings.pkl']

# %%
x_train_pro = pd.read_pickle('current-data-dump/embeddings-dump/training_pro_argument_embeddings.pkl')
y_train_pro = pd.read_pickle('current-data-dump/embeddings-dump/training_pro_evidence_embeddings.pkl')
x_test_pro = pd.read_pickle('current-data-dump/embeddings-dump/test_pro_argument_embeddings.pkl')
y_test_pro = pd.read_pickle('current-data-dump/embeddings-dump/test_pro_evidence_embeddings.pkl')

# %%
x_train_counter = pd.read_pickle('current-data-dump/embeddings-dump/training_counter_argument_embeddings.pkl')
y_train_counter = pd.read_pickle('current-data-dump/embeddings-dump/training_counter_evidence_embeddings.pkl')
x_test_counter = pd.read_pickle('current-data-dump/embeddings-dump/test_counter_argument_embeddings.pkl')
y_test_counter = pd.read_pickle('current-data-dump/embeddings-dump/test_counter_evidence_embeddings.pkl')

# %%
x_train_pro = x_train_pro.drop(columns=['argument'])
y_train_pro = y_train_pro.drop(columns=['evidence'])
x_test_pro = x_test_pro.drop(columns=['argument'])
y_test_pro = y_test_pro.drop(columns=['evidence'])

# %%
x_train_counter = x_train_counter.drop(columns=['argument'])
y_train_counter = y_train_counter.drop(columns=['evidence'])
x_test_counter = x_test_counter.drop(columns=['argument'])
y_test_counter = y_test_counter.drop(columns=['evidence'])

# %%
x_train_combined = pd.concat([x_train_pro, x_train_counter])
y_train_combined = pd.concat([y_train_pro, y_train_counter])
x_test_combined = pd.concat([x_test_pro, x_test_counter])
y_test_combined = pd.concat([y_test_pro, y_test_counter])

# %% [markdown]
# ### Make global data shuffled

# %%
y_train_shuffled = y_train_combined.copy().sample(frac=1).reset_index(drop=True)
y_train_pro_shuffled = y_train_pro.copy().sample(frac=1).reset_index(drop=True)
y_train_counter_shuffled = y_train_counter.copy().sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ### Save global training df

# %%
x_train_combined_folder_path = 'current-data-dump/ada003-autoencoder/'
x_train_combined_file_path = f'{x_train_combined_folder_path}x_train_combined.pkl'
y_train_combined_folder_path = 'current-data-dump/ada003-autoencoder/'
y_train_combined_file_path = f'{x_train_combined_folder_path}y_train_combined.pkl'
os.makedirs(x_train_combined_folder_path, exist_ok=True)
os.makedirs(y_train_combined_folder_path, exist_ok=True)
with open(x_train_combined_file_path, 'wb') as file:
  pickle.dump(x_train_combined, file)
  print(f"File uploaded to {x_train_combined_file_path}")
with open(y_train_combined_file_path, 'wb') as file:
  pickle.dump(y_train_combined, file)
  print(f"File uploaded to {y_train_combined_file_path}")
# Out:
# File uploaded to current-data-dump/ada003-autoencoder/x_train_combined.pkl
# File uploaded to current-data-dump/ada003-autoencoder/y_train_combined.pkl

# %%
x_test_combined_folder_path = 'current-data-dump/ada003-autoencoder/'
x_test_combined_file_path = f'{x_test_combined_folder_path}x_test_combined.pkl'
y_test_combined_folder_path = 'current-data-dump/ada003-autoencoder/'
y_test_combined_file_path = f'{x_test_combined_folder_path}y_test_combined.pkl'
os.makedirs(x_test_combined_folder_path, exist_ok=True)
os.makedirs(y_test_combined_folder_path, exist_ok=True)
with open(x_test_combined_file_path, 'wb') as file:
  pickle.dump(x_test_combined, file)
  print(f"File uploaded to {x_test_combined_file_path}")
with open(y_test_combined_file_path, 'wb') as file:
  pickle.dump(y_test_combined, file)
  print(f"File uploaded to {y_test_combined_file_path}")
# Out:
# File uploaded to current-data-dump/ada003-autoencoder/x_test_combined.pkl
# File uploaded to current-data-dump/ada003-autoencoder/y_test_combined.pkl

# %%
x_train_pro_folder_path = 'current-data-dump/ada003-autoencoder/'
x_train_pro_file_path = f'{x_train_pro_folder_path}x_train_pro.pkl'
y_train_pro_folder_path = 'current-data-dump/ada003-autoencoder/'
y_train_pro_file_path = f'{x_train_pro_folder_path}y_train_pro.pkl'
os.makedirs(x_train_pro_folder_path, exist_ok=True)
os.makedirs(y_train_pro_folder_path, exist_ok=True)
with open(x_train_pro_file_path, 'wb') as file:
  pickle.dump(x_train_pro, file)
  print(f"File uploaded to {x_train_pro_file_path}")
with open(y_train_pro_file_path, 'wb') as file:
  pickle.dump(y_train_pro, file)
  print(f"File uploaded to {y_train_pro_file_path}")
# Out:
# File uploaded to current-data-dump/ada003-autoencoder/x_train_pro.pkl
# File uploaded to current-data-dump/ada003-autoencoder/y_train_pro.pkl

# %%
x_test_pro_folder_path = 'current-data-dump/ada003-autoencoder/'
x_test_pro_file_path = f'{x_test_pro_folder_path}x_test_pro.pkl'
y_test_pro_folder_path = 'current-data-dump/ada003-autoencoder/'
y_test_pro_file_path = f'{x_test_pro_folder_path}y_test_pro.pkl'
os.makedirs(x_test_pro_folder_path, exist_ok=True)
os.makedirs(y_test_pro_folder_path, exist_ok=True)
with open(x_test_pro_file_path, 'wb') as file:
  pickle.dump(x_test_pro, file)
  print(f"File uploaded to {x_test_pro_file_path}")
with open(y_test_pro_file_path, 'wb') as file:
  pickle.dump(y_test_pro, file)
  print(f"File uploaded to {y_test_pro_file_path}")
# Out:
# File uploaded to current-data-dump/ada003-autoencoder/x_test_pro.pkl
# File uploaded to current-data-dump/ada003-autoencoder/y_test_pro.pkl

# %%
x_train_counter_folder_path = 'current-data-dump/ada003-autoencoder/'
x_train_counter_file_path = f'{x_train_counter_folder_path}x_train_counter.pkl'
y_train_counter_folder_path = 'current-data-dump/ada003-autoencoder/'
y_train_counter_file_path = f'{x_train_counter_folder_path}y_train_counter.pkl'
os.makedirs(x_train_counter_folder_path, exist_ok=True)
os.makedirs(y_train_counter_folder_path, exist_ok=True)
with open(x_train_counter_file_path, 'wb') as file:
  pickle.dump(x_train_counter, file)
  print(f"File uploaded to {x_train_counter_file_path}")
with open(y_train_counter_file_path, 'wb') as file:
  pickle.dump(y_train_counter, file)
  print(f"File uploaded to {y_train_counter_file_path}")
# Out:
# File uploaded to current-data-dump/ada003-autoencoder/x_train_counter.pkl
# File uploaded to current-data-dump/ada003-autoencoder/y_train_counter.pkl

# %%
x_test_counter_folder_path = 'current-data-dump/ada003-autoencoder/'
x_test_counter_file_path = f'{x_test_counter_folder_path}x_test_counter.pkl'
y_test_counter_folder_path = 'current-data-dump/ada003-autoencoder/'
y_test_counter_file_path = f'{x_test_counter_folder_path}y_test_counter.pkl'
os.makedirs(x_test_counter_folder_path, exist_ok=True)
os.makedirs(y_test_counter_folder_path, exist_ok=True)
with open(x_test_counter_file_path, 'wb') as file:
  pickle.dump(x_test_counter, file)
  print(f"File uploaded to {x_test_counter_file_path}")
with open(y_test_counter_file_path, 'wb') as file:
  pickle.dump(y_test_counter, file)
  print(f"File uploaded to {y_test_counter_file_path}")
# Out:
# File uploaded to current-data-dump/ada003-autoencoder/x_test_counter.pkl
# File uploaded to current-data-dump/ada003-autoencoder/y_test_counter.pkl

# %% [markdown]
# ## Model

# %% [markdown]
# ### Architecture

# %%
# Layers
input_layer = tf.keras.layers.Input(shape=(1536, ), name="Input")
hidden_layer = tf.keras.layers.Dense(units=1536, activation="relu", name="Hidden")(input_layer)
output_layer = tf.keras.layers.Dense(units=1536, activation="linear", name="Output")(hidden_layer)

# %%
# Model
autoencoder_model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
autoencoder_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 1536)]            0
#
#  Hidden (Dense)              (None, 1536)              2360832
#
#  Output (Dense)              (None, 1536)              2360832
#
# =================================================================
# Total params: 4721664 (18.01 MB)
# Trainable params: 4721664 (18.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Metric

# %%
@tf.keras.saving.register_keras_serializable()
def metric_choose_argument_combined_y_train(y_true, y_pred):
  """combined_metric"""
  combined_training_df_32 = tf.cast(pd.concat([x_train_combined, y_train_combined, x_test_combined, y_test_combined]), dtype=tf.float32)

  cos_sim_pred = tf.matmul(combined_training_df_32, y_pred, transpose_b=True) / tf.reshape(tf.norm(y_pred) * tf.norm(combined_training_df_32, axis=1), [-1, 1])
  cos_sim_true = tf.matmul(combined_training_df_32, y_true, transpose_b=True) / tf.reshape(tf.norm(y_true) * tf.norm(combined_training_df_32, axis=1), [-1, 1])

  max_cos_sim_pred = tf.math.argmax(cos_sim_pred)
  max_cos_sim_true = tf.math.argmax(cos_sim_true)

  return tf.math.count_nonzero(tf.equal(max_cos_sim_pred, max_cos_sim_true))

# %%
@tf.keras.saving.register_keras_serializable()
def metric_choose_argument_pro_y_train(y_true, y_pred):
  """pro_metric"""
  pro_training_df_32 = tf.cast(pd.concat([x_train_pro, y_train_pro, x_test_pro, y_test_pro]), dtype=tf.float32)

  cos_sim_pred = tf.matmul(pro_training_df_32, y_pred, transpose_b=True) / tf.reshape(tf.norm(y_pred) * tf.norm(pro_training_df_32, axis=1), [-1, 1])
  cos_sim_true = tf.matmul(pro_training_df_32, y_true, transpose_b=True) / tf.reshape(tf.norm(y_true) * tf.norm(pro_training_df_32, axis=1), [-1, 1])

  max_cos_sim_pred = tf.math.argmax(cos_sim_pred)
  max_cos_sim_true = tf.math.argmax(cos_sim_true)

  return tf.math.count_nonzero(tf.equal(max_cos_sim_pred, max_cos_sim_true))

# %%
@tf.keras.saving.register_keras_serializable()
def metric_choose_argument_counter_y_train(y_true, y_pred):
  """counter_metric"""
  counter_training_df_32 = tf.cast(pd.concat([x_train_counter, y_train_counter, x_test_counter, y_test_counter]), dtype=tf.float32)

  cos_sim_pred = tf.matmul(counter_training_df_32, y_pred, transpose_b=True) / tf.reshape(tf.norm(y_pred) * tf.norm(counter_training_df_32, axis=1), [-1, 1])
  cos_sim_true = tf.matmul(counter_training_df_32, y_true, transpose_b=True) / tf.reshape(tf.norm(y_true) * tf.norm(counter_training_df_32, axis=1), [-1, 1])

  max_cos_sim_pred = tf.math.argmax(cos_sim_pred)
  max_cos_sim_true = tf.math.argmax(cos_sim_true)

  return tf.math.count_nonzero(tf.equal(max_cos_sim_pred, max_cos_sim_true))

# %% [markdown]
# ### Combined Training

# %%
# combined Model
combined_autoencoder_model = tf.keras.models.clone_model(autoencoder_model)
combined_autoencoder_model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_combined_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='combined_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='combined_training_log.csv', separator=',', append=True)
combined_history = combined_autoencoder_model.fit(
  x=x_train_combined,
  y=y_train_combined,
  batch_size=1,
  epochs=100,
  validation_data = (x_test_combined, y_test_combined),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.5424 - metric_choose_argument_combined_y_train: 0.0256
# Epoch 1: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 8s 6ms/step - loss: -0.5439 - metric_choose_argument_combined_y_train: 0.0278 - val_loss: -0.6271 - val_metric_choose_argument_combined_y_train: 0.1277
# Epoch 2/100
# 383/396 [============================>.] - ETA: 0s - loss: -0.6819 - metric_choose_argument_combined_y_train: 0.2794
# Epoch 2: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.6808 - metric_choose_argument_combined_y_train: 0.2753 - val_loss: -0.6893 - val_metric_choose_argument_combined_y_train: 0.2660
# Epoch 3/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.7798 - metric_choose_argument_combined_y_train: 0.6327
# Epoch 3: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.7793 - metric_choose_argument_combined_y_train: 0.6338 - val_loss: -0.7282 - val_metric_choose_argument_combined_y_train: 0.2553
# Epoch 4/100
# 393/396 [============================>.] - ETA: 0s - loss: -0.8531 - metric_choose_argument_combined_y_train: 0.7150
# Epoch 4: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.8529 - metric_choose_argument_combined_y_train: 0.7172 - val_loss: -0.7443 - val_metric_choose_argument_combined_y_train: 0.2553
# Epoch 5/100
# 389/396 [============================>.] - ETA: 0s - loss: -0.9010 - metric_choose_argument_combined_y_train: 0.7661
# Epoch 5: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9009 - metric_choose_argument_combined_y_train: 0.7626 - val_loss: -0.7522 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 6/100
# 381/396 [===========================>..] - ETA: 0s - loss: -0.9300 - metric_choose_argument_combined_y_train: 0.7769
# Epoch 6: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9295 - metric_choose_argument_combined_y_train: 0.7778 - val_loss: -0.7598 - val_metric_choose_argument_combined_y_train: 0.2660
# Epoch 7/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9479 - metric_choose_argument_combined_y_train: 0.7948
# Epoch 7: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9477 - metric_choose_argument_combined_y_train: 0.7929 - val_loss: -0.7606 - val_metric_choose_argument_combined_y_train: 0.2660
# Epoch 8/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9558 - metric_choose_argument_combined_y_train: 0.7766
# Epoch 8: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9559 - metric_choose_argument_combined_y_train: 0.7778 - val_loss: -0.7650 - val_metric_choose_argument_combined_y_train: 0.2500
# Epoch 9/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9610 - metric_choose_argument_combined_y_train: 0.7959
# Epoch 9: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9607 - metric_choose_argument_combined_y_train: 0.7955 - val_loss: -0.7638 - val_metric_choose_argument_combined_y_train: 0.2660
# Epoch 10/100
# 383/396 [============================>.] - ETA: 0s - loss: -0.9647 - metric_choose_argument_combined_y_train: 0.8094
# Epoch 10: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9643 - metric_choose_argument_combined_y_train: 0.8081 - val_loss: -0.7650 - val_metric_choose_argument_combined_y_train: 0.2766
# Epoch 11/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9688 - metric_choose_argument_combined_y_train: 0.8320
# Epoch 11: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9685 - metric_choose_argument_combined_y_train: 0.8333 - val_loss: -0.7685 - val_metric_choose_argument_combined_y_train: 0.2713
# Epoch 12/100
# 381/396 [===========================>..] - ETA: 0s - loss: -0.9699 - metric_choose_argument_combined_y_train: 0.8136
# Epoch 12: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9695 - metric_choose_argument_combined_y_train: 0.8030 - val_loss: -0.7682 - val_metric_choose_argument_combined_y_train: 0.2766
# Epoch 13/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9712 - metric_choose_argument_combined_y_train: 0.8191
# Epoch 13: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9711 - metric_choose_argument_combined_y_train: 0.8182 - val_loss: -0.7684 - val_metric_choose_argument_combined_y_train: 0.2606
# Epoch 14/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9731 - metric_choose_argument_combined_y_train: 0.8405
# Epoch 14: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9729 - metric_choose_argument_combined_y_train: 0.8384 - val_loss: -0.7724 - val_metric_choose_argument_combined_y_train: 0.2819
# Epoch 15/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9738 - metric_choose_argument_combined_y_train: 0.8405
# Epoch 15: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9738 - metric_choose_argument_combined_y_train: 0.8409 - val_loss: -0.7695 - val_metric_choose_argument_combined_y_train: 0.2713
# Epoch 16/100
# 389/396 [============================>.] - ETA: 0s - loss: -0.9748 - metric_choose_argument_combined_y_train: 0.8303
# Epoch 16: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9748 - metric_choose_argument_combined_y_train: 0.8308 - val_loss: -0.7725 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 17/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9774 - metric_choose_argument_combined_y_train: 0.8491
# Epoch 17: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9773 - metric_choose_argument_combined_y_train: 0.8485 - val_loss: -0.7744 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 18/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9791 - metric_choose_argument_combined_y_train: 0.8426
# Epoch 18: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 3s 6ms/step - loss: -0.9791 - metric_choose_argument_combined_y_train: 0.8409 - val_loss: -0.7749 - val_metric_choose_argument_combined_y_train: 0.3351
# Epoch 19/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9798 - metric_choose_argument_combined_y_train: 0.8608
# Epoch 19: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9798 - metric_choose_argument_combined_y_train: 0.8611 - val_loss: -0.7755 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 20/100
# 389/396 [============================>.] - ETA: 0s - loss: -0.9805 - metric_choose_argument_combined_y_train: 0.8612
# Epoch 20: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9806 - metric_choose_argument_combined_y_train: 0.8636 - val_loss: -0.7759 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 21/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9813 - metric_choose_argument_combined_y_train: 0.8832
# Epoch 21: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9811 - metric_choose_argument_combined_y_train: 0.8813 - val_loss: -0.7754 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 22/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9819 - metric_choose_argument_combined_y_train: 0.8619
# Epoch 22: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9818 - metric_choose_argument_combined_y_train: 0.8611 - val_loss: -0.7767 - val_metric_choose_argument_combined_y_train: 0.2872
# Epoch 23/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9824 - metric_choose_argument_combined_y_train: 0.8759
# Epoch 23: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9824 - metric_choose_argument_combined_y_train: 0.8763 - val_loss: -0.7776 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 24/100
# 393/396 [============================>.] - ETA: 0s - loss: -0.9840 - metric_choose_argument_combined_y_train: 0.8651
# Epoch 24: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 3s 6ms/step - loss: -0.9840 - metric_choose_argument_combined_y_train: 0.8636 - val_loss: -0.7776 - val_metric_choose_argument_combined_y_train: 0.2766
# Epoch 25/100
# 386/396 [============================>.] - ETA: 0s - loss: -0.9850 - metric_choose_argument_combined_y_train: 0.8782
# Epoch 25: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9845 - metric_choose_argument_combined_y_train: 0.8788 - val_loss: -0.7791 - val_metric_choose_argument_combined_y_train: 0.3191
# Epoch 26/100
# 382/396 [===========================>..] - ETA: 0s - loss: -0.9849 - metric_choose_argument_combined_y_train: 0.8717
# Epoch 26: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9850 - metric_choose_argument_combined_y_train: 0.8737 - val_loss: -0.7778 - val_metric_choose_argument_combined_y_train: 0.2553
# Epoch 27/100
# 383/396 [============================>.] - ETA: 0s - loss: -0.9850 - metric_choose_argument_combined_y_train: 0.8668
# Epoch 27: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9852 - metric_choose_argument_combined_y_train: 0.8636 - val_loss: -0.7816 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 28/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9860 - metric_choose_argument_combined_y_train: 0.8821
# Epoch 28: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9860 - metric_choose_argument_combined_y_train: 0.8838 - val_loss: -0.7799 - val_metric_choose_argument_combined_y_train: 0.2713
# Epoch 29/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9868 - metric_choose_argument_combined_y_train: 0.8675
# Epoch 29: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9868 - metric_choose_argument_combined_y_train: 0.8712 - val_loss: -0.7818 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 30/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9878 - metric_choose_argument_combined_y_train: 0.9005
# Epoch 30: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9878 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7826 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 31/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9877 - metric_choose_argument_combined_y_train: 0.9013
# Epoch 31: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9878 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7827 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 32/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9878 - metric_choose_argument_combined_y_train: 0.8883
# Epoch 32: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9878 - metric_choose_argument_combined_y_train: 0.8889 - val_loss: -0.7804 - val_metric_choose_argument_combined_y_train: 0.3298
# Epoch 33/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9893 - metric_choose_argument_combined_y_train: 0.8883
# Epoch 33: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9893 - metric_choose_argument_combined_y_train: 0.8914 - val_loss: -0.7824 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 34/100
# 382/396 [===========================>..] - ETA: 0s - loss: -0.9892 - metric_choose_argument_combined_y_train: 0.9084
# Epoch 34: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9892 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7837 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 35/100
# 381/396 [===========================>..] - ETA: 0s - loss: -0.9892 - metric_choose_argument_combined_y_train: 0.8793
# Epoch 35: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9892 - metric_choose_argument_combined_y_train: 0.8788 - val_loss: -0.7821 - val_metric_choose_argument_combined_y_train: 0.3298
# Epoch 36/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9890 - metric_choose_argument_combined_y_train: 0.9031
# Epoch 36: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 4s 9ms/step - loss: -0.9890 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7834 - val_metric_choose_argument_combined_y_train: 0.3191
# Epoch 37/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9898 - metric_choose_argument_combined_y_train: 0.8864
# Epoch 37: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9898 - metric_choose_argument_combined_y_train: 0.8864 - val_loss: -0.7828 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 38/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9910 - metric_choose_argument_combined_y_train: 0.8776
# Epoch 38: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9910 - metric_choose_argument_combined_y_train: 0.8788 - val_loss: -0.7833 - val_metric_choose_argument_combined_y_train: 0.3191
# Epoch 39/100
# 384/396 [============================>.] - ETA: 0s - loss: -0.9914 - metric_choose_argument_combined_y_train: 0.8906
# Epoch 39: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9914 - metric_choose_argument_combined_y_train: 0.8939 - val_loss: -0.7848 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 40/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9916 - metric_choose_argument_combined_y_train: 0.9005
# Epoch 40: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9916 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7833 - val_metric_choose_argument_combined_y_train: 0.2819
# Epoch 41/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9919 - metric_choose_argument_combined_y_train: 0.8903
# Epoch 41: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9919 - metric_choose_argument_combined_y_train: 0.8914 - val_loss: -0.7852 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 42/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9918 - metric_choose_argument_combined_y_train: 0.9063
# Epoch 42: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9917 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7855 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 43/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9918 - metric_choose_argument_combined_y_train: 0.8821
# Epoch 43: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9918 - metric_choose_argument_combined_y_train: 0.8838 - val_loss: -0.7861 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 44/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9919 - metric_choose_argument_combined_y_train: 0.9013
# Epoch 44: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9919 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7849 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 45/100
# 382/396 [===========================>..] - ETA: 0s - loss: -0.9923 - metric_choose_argument_combined_y_train: 0.8953
# Epoch 45: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9924 - metric_choose_argument_combined_y_train: 0.8939 - val_loss: -0.7861 - val_metric_choose_argument_combined_y_train: 0.2872
# Epoch 46/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9928 - metric_choose_argument_combined_y_train: 0.8883
# Epoch 46: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9928 - metric_choose_argument_combined_y_train: 0.8889 - val_loss: -0.7863 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 47/100
# 381/396 [===========================>..] - ETA: 0s - loss: -0.9924 - metric_choose_argument_combined_y_train: 0.8845
# Epoch 47: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9924 - metric_choose_argument_combined_y_train: 0.8838 - val_loss: -0.7868 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 48/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9918 - metric_choose_argument_combined_y_train: 0.9091
# Epoch 48: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9919 - metric_choose_argument_combined_y_train: 0.9116 - val_loss: -0.7848 - val_metric_choose_argument_combined_y_train: 0.3191
# Epoch 49/100
# 382/396 [===========================>..] - ETA: 0s - loss: -0.9924 - metric_choose_argument_combined_y_train: 0.8770
# Epoch 49: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9925 - metric_choose_argument_combined_y_train: 0.8788 - val_loss: -0.7865 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 50/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9930 - metric_choose_argument_combined_y_train: 0.8965
# Epoch 50: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9930 - metric_choose_argument_combined_y_train: 0.8965 - val_loss: -0.7856 - val_metric_choose_argument_combined_y_train: 0.3404
# Epoch 51/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9936 - metric_choose_argument_combined_y_train: 0.8990
# Epoch 51: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9936 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7873 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 52/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.9116
# Epoch 52: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.9116 - val_loss: -0.7867 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 53/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.8863
# Epoch 53: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9938 - metric_choose_argument_combined_y_train: 0.8838 - val_loss: -0.7867 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 54/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9938 - metric_choose_argument_combined_y_train: 0.9038
# Epoch 54: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9938 - metric_choose_argument_combined_y_train: 0.9040 - val_loss: -0.7872 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 55/100
# 384/396 [============================>.] - ETA: 0s - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.9141
# Epoch 55: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.9141 - val_loss: -0.7870 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 56/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9938 - metric_choose_argument_combined_y_train: 0.9000
# Epoch 56: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9938 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7865 - val_metric_choose_argument_combined_y_train: 0.3191
# Epoch 57/100
# 386/396 [============================>.] - ETA: 0s - loss: -0.9936 - metric_choose_argument_combined_y_train: 0.8834
# Epoch 57: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9936 - metric_choose_argument_combined_y_train: 0.8813 - val_loss: -0.7868 - val_metric_choose_argument_combined_y_train: 0.2713
# Epoch 58/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.9158
# Epoch 58: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9937 - metric_choose_argument_combined_y_train: 0.9141 - val_loss: -0.7877 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 59/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9940 - metric_choose_argument_combined_y_train: 0.9065
# Epoch 59: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9941 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7877 - val_metric_choose_argument_combined_y_train: 0.3351
# Epoch 60/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9941 - metric_choose_argument_combined_y_train: 0.8861
# Epoch 60: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9941 - metric_choose_argument_combined_y_train: 0.8864 - val_loss: -0.7886 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 61/100
# 393/396 [============================>.] - ETA: 0s - loss: -0.9945 - metric_choose_argument_combined_y_train: 0.8906
# Epoch 61: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9945 - metric_choose_argument_combined_y_train: 0.8914 - val_loss: -0.7870 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 62/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9945 - metric_choose_argument_combined_y_train: 0.8897
# Epoch 62: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9945 - metric_choose_argument_combined_y_train: 0.8889 - val_loss: -0.7877 - val_metric_choose_argument_combined_y_train: 0.3404
# Epoch 63/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9947 - metric_choose_argument_combined_y_train: 0.9061
# Epoch 63: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9946 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7875 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 64/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9946 - metric_choose_argument_combined_y_train: 0.8875
# Epoch 64: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9947 - metric_choose_argument_combined_y_train: 0.8889 - val_loss: -0.7877 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 65/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9946 - metric_choose_argument_combined_y_train: 0.9207
# Epoch 65: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9946 - metric_choose_argument_combined_y_train: 0.9217 - val_loss: -0.7872 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 66/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9946 - metric_choose_argument_combined_y_train: 0.8782
# Epoch 66: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9946 - metric_choose_argument_combined_y_train: 0.8788 - val_loss: -0.7889 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 67/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9948 - metric_choose_argument_combined_y_train: 0.8941
# Epoch 67: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9948 - metric_choose_argument_combined_y_train: 0.8965 - val_loss: -0.7893 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 68/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9949 - metric_choose_argument_combined_y_train: 0.9054
# Epoch 68: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9950 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7888 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 69/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9951 - metric_choose_argument_combined_y_train: 0.8990
# Epoch 69: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9951 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7882 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 70/100
# 393/396 [============================>.] - ETA: 0s - loss: -0.9953 - metric_choose_argument_combined_y_train: 0.8931
# Epoch 70: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9953 - metric_choose_argument_combined_y_train: 0.8939 - val_loss: -0.7887 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 71/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9952 - metric_choose_argument_combined_y_train: 0.9258
# Epoch 71: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9953 - metric_choose_argument_combined_y_train: 0.9242 - val_loss: -0.7881 - val_metric_choose_argument_combined_y_train: 0.3351
# Epoch 72/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9954 - metric_choose_argument_combined_y_train: 0.9015
# Epoch 72: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9954 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7892 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 73/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9956 - metric_choose_argument_combined_y_train: 0.8990
# Epoch 73: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9956 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7894 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 74/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9953 - metric_choose_argument_combined_y_train: 0.9038
# Epoch 74: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9953 - metric_choose_argument_combined_y_train: 0.9040 - val_loss: -0.7883 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 75/100
# 386/396 [============================>.] - ETA: 0s - loss: -0.9952 - metric_choose_argument_combined_y_train: 0.9041
# Epoch 75: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9952 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7896 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 76/100
# 386/396 [============================>.] - ETA: 0s - loss: -0.9954 - metric_choose_argument_combined_y_train: 0.9197
# Epoch 76: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9954 - metric_choose_argument_combined_y_train: 0.9192 - val_loss: -0.7888 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 77/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9957 - metric_choose_argument_combined_y_train: 0.8990
# Epoch 77: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9957 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7902 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 78/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.8959
# Epoch 78: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 3s 6ms/step - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.8965 - val_loss: -0.7892 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 79/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9963 - metric_choose_argument_combined_y_train: 0.8974
# Epoch 79: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9963 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7895 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 80/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.9000
# Epoch 80: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7892 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 81/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9959 - metric_choose_argument_combined_y_train: 0.9066
# Epoch 81: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9959 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7894 - val_metric_choose_argument_combined_y_train: 0.3191
# Epoch 82/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9956 - metric_choose_argument_combined_y_train: 0.8909
# Epoch 82: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9957 - metric_choose_argument_combined_y_train: 0.8914 - val_loss: -0.7887 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 83/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9960 - metric_choose_argument_combined_y_train: 0.9199
# Epoch 83: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9960 - metric_choose_argument_combined_y_train: 0.9192 - val_loss: -0.7889 - val_metric_choose_argument_combined_y_train: 0.3457
# Epoch 84/100
# 384/396 [============================>.] - ETA: 0s - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.9062
# Epoch 84: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7899 - val_metric_choose_argument_combined_y_train: 0.2872
# Epoch 85/100
# 381/396 [===========================>..] - ETA: 0s - loss: -0.9964 - metric_choose_argument_combined_y_train: 0.9265
# Epoch 85: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9964 - metric_choose_argument_combined_y_train: 0.9293 - val_loss: -0.7905 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 86/100
# 392/396 [============================>.] - ETA: 0s - loss: -0.9964 - metric_choose_argument_combined_y_train: 0.9056
# Epoch 86: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9964 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7897 - val_metric_choose_argument_combined_y_train: 0.3298
# Epoch 87/100
# 384/396 [============================>.] - ETA: 0s - loss: -0.9963 - metric_choose_argument_combined_y_train: 0.8984
# Epoch 87: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9963 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7898 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 88/100
# 386/396 [============================>.] - ETA: 0s - loss: -0.9964 - metric_choose_argument_combined_y_train: 0.8834
# Epoch 88: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9964 - metric_choose_argument_combined_y_train: 0.8864 - val_loss: -0.7904 - val_metric_choose_argument_combined_y_train: 0.3032
# Epoch 89/100
# 395/396 [============================>.] - ETA: 0s - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.9013
# Epoch 89: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9962 - metric_choose_argument_combined_y_train: 0.9015 - val_loss: -0.7897 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 90/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9965 - metric_choose_argument_combined_y_train: 0.9105
# Epoch 90: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9965 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7901 - val_metric_choose_argument_combined_y_train: 0.3404
# Epoch 91/100
# 394/396 [============================>.] - ETA: 0s - loss: -0.9966 - metric_choose_argument_combined_y_train: 0.9036
# Epoch 91: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9966 - metric_choose_argument_combined_y_train: 0.9040 - val_loss: -0.7909 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 92/100
# 385/396 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.9169
# Epoch 92: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.9192 - val_loss: -0.7903 - val_metric_choose_argument_combined_y_train: 0.3245
# Epoch 93/100
# 387/396 [============================>.] - ETA: 0s - loss: -0.9968 - metric_choose_argument_combined_y_train: 0.9121
# Epoch 93: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9968 - metric_choose_argument_combined_y_train: 0.9091 - val_loss: -0.7906 - val_metric_choose_argument_combined_y_train: 0.2979
# Epoch 94/100
# 396/396 [==============================] - ETA: 0s - loss: -0.9968 - metric_choose_argument_combined_y_train: 0.9066
# Epoch 94: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9968 - metric_choose_argument_combined_y_train: 0.9066 - val_loss: -0.7907 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 95/100
# 391/396 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.8977
# Epoch 95: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7906 - val_metric_choose_argument_combined_y_train: 0.2926
# Epoch 96/100
# 386/396 [============================>.] - ETA: 0s - loss: -0.9966 - metric_choose_argument_combined_y_train: 0.8938
# Epoch 96: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.8965 - val_loss: -0.7907 - val_metric_choose_argument_combined_y_train: 0.2819
# Epoch 97/100
# 390/396 [============================>.] - ETA: 0s - loss: -0.9968 - metric_choose_argument_combined_y_train: 0.8974
# Epoch 97: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 6ms/step - loss: -0.9968 - metric_choose_argument_combined_y_train: 0.8990 - val_loss: -0.7910 - val_metric_choose_argument_combined_y_train: 0.3457
# Epoch 98/100
# 384/396 [============================>.] - ETA: 0s - loss: -0.9970 - metric_choose_argument_combined_y_train: 0.8906
# Epoch 98: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9970 - metric_choose_argument_combined_y_train: 0.8889 - val_loss: -0.7903 - val_metric_choose_argument_combined_y_train: 0.3085
# Epoch 99/100
# 393/396 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.9237
# Epoch 99: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9967 - metric_choose_argument_combined_y_train: 0.9242 - val_loss: -0.7904 - val_metric_choose_argument_combined_y_train: 0.3138
# Epoch 100/100
# 389/396 [============================>.] - ETA: 0s - loss: -0.9961 - metric_choose_argument_combined_y_train: 0.8920
# Epoch 100: saving model to combined_autoencoder_weights.keras
# 396/396 [==============================] - 2s 5ms/step - loss: -0.9961 - metric_choose_argument_combined_y_train: 0.8914 - val_loss: -0.7908 - val_metric_choose_argument_combined_y_train: 0.3245

# %%
global_history_df = pd.DataFrame(combined_history.history)

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
global_history_df.to_csv(f'{output_folder_path}combined_training_log.csv')

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
combined_autoencoder_model.save(f'{output_folder_path}combined_autoencoder_model.keras')

# %% [markdown]
# ### Combined Shuffled Training

# %%
# combined Shuffled Model
combined_shuffled_autoencoder_model = tf.keras.models.clone_model(autoencoder_model)
combined_shuffled_autoencoder_model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_combined_y_train]
)

combined_shuffled_history = combined_shuffled_autoencoder_model.fit(
  x=x_train_combined,
  y=y_train_shuffled,
  batch_size=1,
  epochs=20,
  validation_data = (x_test_combined, y_test_combined)
)
# Out:
# Epoch 1/20
# 396/396 [==============================] - 3s 5ms/step - loss: -0.4717 - metric_choose_argument_combined_y_train: 0.0025 - val_loss: -0.4804 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 2/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.5007 - metric_choose_argument_combined_y_train: 0.0000e+00 - val_loss: -0.4762 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 3/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.5452 - metric_choose_argument_combined_y_train: 0.0934 - val_loss: -0.4486 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 4/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.6352 - metric_choose_argument_combined_y_train: 0.4040 - val_loss: -0.4116 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 5/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.7312 - metric_choose_argument_combined_y_train: 0.6364 - val_loss: -0.3693 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 6/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.8079 - metric_choose_argument_combined_y_train: 0.7146 - val_loss: -0.3458 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 7/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.8548 - metric_choose_argument_combined_y_train: 0.7273 - val_loss: -0.3220 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 8/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.8813 - metric_choose_argument_combined_y_train: 0.7348 - val_loss: -0.3176 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 9/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.8973 - metric_choose_argument_combined_y_train: 0.7626 - val_loss: -0.3203 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 10/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9113 - metric_choose_argument_combined_y_train: 0.7854 - val_loss: -0.3089 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 11/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9175 - metric_choose_argument_combined_y_train: 0.7879 - val_loss: -0.3139 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 12/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9250 - metric_choose_argument_combined_y_train: 0.7778 - val_loss: -0.3046 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 13/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9314 - metric_choose_argument_combined_y_train: 0.8081 - val_loss: -0.3127 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 14/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9363 - metric_choose_argument_combined_y_train: 0.8106 - val_loss: -0.2993 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 15/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9404 - metric_choose_argument_combined_y_train: 0.8308 - val_loss: -0.2998 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 16/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9445 - metric_choose_argument_combined_y_train: 0.8207 - val_loss: -0.3044 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 17/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9452 - metric_choose_argument_combined_y_train: 0.8384 - val_loss: -0.3031 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 18/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9512 - metric_choose_argument_combined_y_train: 0.8333 - val_loss: -0.3052 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 19/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9527 - metric_choose_argument_combined_y_train: 0.8510 - val_loss: -0.3045 - val_metric_choose_argument_combined_y_train: 0.0000e+00
# Epoch 20/20
# 396/396 [==============================] - 1s 3ms/step - loss: -0.9592 - metric_choose_argument_combined_y_train: 0.8586 - val_loss: -0.3035 - val_metric_choose_argument_combined_y_train: 0.0000e+00

# %%
combined_shuffled_history_df = pd.DataFrame(combined_shuffled_history.history)

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
combined_shuffled_history_df.to_csv(f'{output_folder_path}combined_shuffled_training_log.csv')

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
combined_shuffled_autoencoder_model.save(f'{output_folder_path}combined_shuffled_autoencoder_model.keras')

# %% [markdown]
# ### Pro Training

# %%
# pro Model
pro_autoencoder_model = tf.keras.models.clone_model(autoencoder_model)
pro_autoencoder_model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_pro_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='pro_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='pro_training_log.csv', separator=',', append=True)
pro_history = pro_autoencoder_model.fit(
  x=x_train_pro,
  y=y_train_pro,
  batch_size=1,
  epochs=20,
  validation_data = (x_test_pro, y_test_pro),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/20
# 325/332 [============================>.] - ETA: 0s - loss: -0.5319 - metric_choose_argument_pro_y_train: 0.0154
# Epoch 1: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 3s 5ms/step - loss: -0.5334 - metric_choose_argument_pro_y_train: 0.0211 - val_loss: -0.5790 - val_metric_choose_argument_pro_y_train: 0.0323
# Epoch 2/20
# 331/332 [============================>.] - ETA: 0s - loss: -0.6620 - metric_choose_argument_pro_y_train: 0.3353
# Epoch 2: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.6617 - metric_choose_argument_pro_y_train: 0.3343 - val_loss: -0.6155 - val_metric_choose_argument_pro_y_train: 0.1613
# Epoch 3/20
# 320/332 [===========================>..] - ETA: 0s - loss: -0.7657 - metric_choose_argument_pro_y_train: 0.7406
# Epoch 3: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.7631 - metric_choose_argument_pro_y_train: 0.7259 - val_loss: -0.6293 - val_metric_choose_argument_pro_y_train: 0.1694
# Epoch 4/20
# 326/332 [============================>.] - ETA: 0s - loss: -0.8449 - metric_choose_argument_pro_y_train: 0.8650
# Epoch 4: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.8440 - metric_choose_argument_pro_y_train: 0.8645 - val_loss: -0.6340 - val_metric_choose_argument_pro_y_train: 0.1694
# Epoch 5/20
# 331/332 [============================>.] - ETA: 0s - loss: -0.8986 - metric_choose_argument_pro_y_train: 0.8973
# Epoch 5: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.8986 - metric_choose_argument_pro_y_train: 0.8976 - val_loss: -0.6384 - val_metric_choose_argument_pro_y_train: 0.1774
# Epoch 6/20
# 318/332 [===========================>..] - ETA: 0s - loss: -0.9341 - metric_choose_argument_pro_y_train: 0.8994
# Epoch 6: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9327 - metric_choose_argument_pro_y_train: 0.8976 - val_loss: -0.6330 - val_metric_choose_argument_pro_y_train: 0.1694
# Epoch 7/20
# 319/332 [===========================>..] - ETA: 0s - loss: -0.9514 - metric_choose_argument_pro_y_train: 0.9091
# Epoch 7: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9510 - metric_choose_argument_pro_y_train: 0.9066 - val_loss: -0.6379 - val_metric_choose_argument_pro_y_train: 0.1613
# Epoch 8/20
# 323/332 [============================>.] - ETA: 0s - loss: -0.9631 - metric_choose_argument_pro_y_train: 0.9412
# Epoch 8: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9627 - metric_choose_argument_pro_y_train: 0.9398 - val_loss: -0.6350 - val_metric_choose_argument_pro_y_train: 0.1613
# Epoch 9/20
# 324/332 [============================>.] - ETA: 0s - loss: -0.9678 - metric_choose_argument_pro_y_train: 0.9321
# Epoch 9: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9678 - metric_choose_argument_pro_y_train: 0.9337 - val_loss: -0.6339 - val_metric_choose_argument_pro_y_train: 0.1613
# Epoch 10/20
# 325/332 [============================>.] - ETA: 0s - loss: -0.9711 - metric_choose_argument_pro_y_train: 0.9508
# Epoch 10: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9709 - metric_choose_argument_pro_y_train: 0.9458 - val_loss: -0.6364 - val_metric_choose_argument_pro_y_train: 0.1371
# Epoch 11/20
# 330/332 [============================>.] - ETA: 0s - loss: -0.9736 - metric_choose_argument_pro_y_train: 0.9485
# Epoch 11: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9736 - metric_choose_argument_pro_y_train: 0.9488 - val_loss: -0.6390 - val_metric_choose_argument_pro_y_train: 0.1774
# Epoch 12/20
# 322/332 [============================>.] - ETA: 0s - loss: -0.9761 - metric_choose_argument_pro_y_train: 0.9534
# Epoch 12: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9755 - metric_choose_argument_pro_y_train: 0.9518 - val_loss: -0.6414 - val_metric_choose_argument_pro_y_train: 0.1371
# Epoch 13/20
# 314/332 [===========================>..] - ETA: 0s - loss: -0.9768 - metric_choose_argument_pro_y_train: 0.9427
# Epoch 13: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9770 - metric_choose_argument_pro_y_train: 0.9458 - val_loss: -0.6384 - val_metric_choose_argument_pro_y_train: 0.1290
# Epoch 14/20
# 329/332 [============================>.] - ETA: 0s - loss: -0.9782 - metric_choose_argument_pro_y_train: 0.9574
# Epoch 14: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9782 - metric_choose_argument_pro_y_train: 0.9578 - val_loss: -0.6405 - val_metric_choose_argument_pro_y_train: 0.1371
# Epoch 15/20
# 321/332 [============================>.] - ETA: 0s - loss: -0.9793 - metric_choose_argument_pro_y_train: 0.9533
# Epoch 15: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9794 - metric_choose_argument_pro_y_train: 0.9548 - val_loss: -0.6431 - val_metric_choose_argument_pro_y_train: 0.1532
# Epoch 16/20
# 328/332 [============================>.] - ETA: 0s - loss: -0.9797 - metric_choose_argument_pro_y_train: 0.9665
# Epoch 16: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9798 - metric_choose_argument_pro_y_train: 0.9669 - val_loss: -0.6455 - val_metric_choose_argument_pro_y_train: 0.1452
# Epoch 17/20
# 321/332 [============================>.] - ETA: 0s - loss: -0.9809 - metric_choose_argument_pro_y_train: 0.9595
# Epoch 17: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9811 - metric_choose_argument_pro_y_train: 0.9608 - val_loss: -0.6439 - val_metric_choose_argument_pro_y_train: 0.1371
# Epoch 18/20
# 321/332 [============================>.] - ETA: 0s - loss: -0.9831 - metric_choose_argument_pro_y_train: 0.9720
# Epoch 18: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9831 - metric_choose_argument_pro_y_train: 0.9729 - val_loss: -0.6452 - val_metric_choose_argument_pro_y_train: 0.1290
# Epoch 19/20
# 327/332 [============================>.] - ETA: 0s - loss: -0.9842 - metric_choose_argument_pro_y_train: 0.9694
# Epoch 19: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9842 - metric_choose_argument_pro_y_train: 0.9699 - val_loss: -0.6467 - val_metric_choose_argument_pro_y_train: 0.1452
# Epoch 20/20
# 331/332 [============================>.] - ETA: 0s - loss: -0.9845 - metric_choose_argument_pro_y_train: 0.9668
# Epoch 20: saving model to pro_autoencoder_weights.keras
# 332/332 [==============================] - 1s 4ms/step - loss: -0.9845 - metric_choose_argument_pro_y_train: 0.9669 - val_loss: -0.6468 - val_metric_choose_argument_pro_y_train: 0.1694

# %%
pro_history_df = pd.DataFrame(pro_history.history)

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
pro_history_df.to_csv(f'{output_folder_path}pro_training_log.csv')

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
pro_autoencoder_model.save(f'{output_folder_path}pro_autoencoder_model.keras')

# %% [markdown]
# ### Pro Shuffled Training

# %%
# pro Shuffled Model
pro_shuffled_autoencoder_model = tf.keras.models.clone_model(autoencoder_model)
pro_shuffled_autoencoder_model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_pro_y_train]
)

pro_shuffled_history = pro_shuffled_autoencoder_model.fit(
  x=x_train_pro,
  y=y_train_pro_shuffled,
  batch_size=1,
  epochs=20,
  validation_data = (x_test_pro, y_test_pro)
)
# Out:
# Epoch 1/20
# 332/332 [==============================] - 3s 5ms/step - loss: -0.4678 - metric_choose_argument_pro_y_train: 0.0000e+00 - val_loss: -0.4730 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 2/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.5009 - metric_choose_argument_pro_y_train: 0.0060 - val_loss: -0.4719 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 3/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.5498 - metric_choose_argument_pro_y_train: 0.1024 - val_loss: -0.4369 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 4/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.6512 - metric_choose_argument_pro_y_train: 0.5512 - val_loss: -0.4016 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 5/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.7663 - metric_choose_argument_pro_y_train: 0.8253 - val_loss: -0.3564 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 6/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.8454 - metric_choose_argument_pro_y_train: 0.8614 - val_loss: -0.3394 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 7/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.8964 - metric_choose_argument_pro_y_train: 0.8916 - val_loss: -0.3268 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 8/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9240 - metric_choose_argument_pro_y_train: 0.9066 - val_loss: -0.3293 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 9/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9403 - metric_choose_argument_pro_y_train: 0.9247 - val_loss: -0.3152 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 10/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9475 - metric_choose_argument_pro_y_train: 0.9247 - val_loss: -0.3198 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 11/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9518 - metric_choose_argument_pro_y_train: 0.9367 - val_loss: -0.3093 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 12/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9583 - metric_choose_argument_pro_y_train: 0.9578 - val_loss: -0.3271 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 13/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9631 - metric_choose_argument_pro_y_train: 0.9518 - val_loss: -0.3229 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 14/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9675 - metric_choose_argument_pro_y_train: 0.9548 - val_loss: -0.3303 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 15/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9699 - metric_choose_argument_pro_y_train: 0.9518 - val_loss: -0.3234 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 16/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9715 - metric_choose_argument_pro_y_train: 0.9578 - val_loss: -0.3347 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 17/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9697 - metric_choose_argument_pro_y_train: 0.9518 - val_loss: -0.3299 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 18/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9718 - metric_choose_argument_pro_y_train: 0.9639 - val_loss: -0.3273 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 19/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9721 - metric_choose_argument_pro_y_train: 0.9759 - val_loss: -0.3312 - val_metric_choose_argument_pro_y_train: 0.0000e+00
# Epoch 20/20
# 332/332 [==============================] - 1s 3ms/step - loss: -0.9746 - metric_choose_argument_pro_y_train: 0.9639 - val_loss: -0.3314 - val_metric_choose_argument_pro_y_train: 0.0000e+00

# %%
pro_shuffled_history_df = pd.DataFrame(pro_shuffled_history.history)

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
pro_shuffled_history_df.to_csv(f'{output_folder_path}pro_shuffled_training_log.csv')

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
pro_shuffled_autoencoder_model.save(f'{output_folder_path}pro_shuffled_autoencoder_model.keras')

# %% [markdown]
# ### Counter Training

# %%
# counter Model
counter_autoencoder_model = tf.keras.models.clone_model(autoencoder_model)
counter_autoencoder_model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_counter_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='counter_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='counter_training_log.csv', separator=',', append=True)
counter_history = counter_autoencoder_model.fit(
  x=x_train_counter,
  y=y_train_counter,
  batch_size=1,
  epochs=20,
  validation_data = (x_test_counter, y_test_counter),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/20
# 60/64 [===========================>..] - ETA: 0s - loss: -0.4287 - metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 1: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 2s 11ms/step - loss: -0.4360 - metric_choose_argument_counter_y_train: 0.0000e+00 - val_loss: -0.5656 - val_metric_choose_argument_counter_y_train: 0.0469
# Epoch 2/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.5976 - metric_choose_argument_counter_y_train: 0.0820
# Epoch 2: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 1s 8ms/step - loss: -0.5937 - metric_choose_argument_counter_y_train: 0.0781 - val_loss: -0.7487 - val_metric_choose_argument_counter_y_train: 0.6719
# Epoch 3/20
# 63/64 [============================>.] - ETA: 0s - loss: -0.7422 - metric_choose_argument_counter_y_train: 0.7778
# Epoch 3: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.7415 - metric_choose_argument_counter_y_train: 0.7656 - val_loss: -0.8586 - val_metric_choose_argument_counter_y_train: 0.7188
# Epoch 4/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.8575 - metric_choose_argument_counter_y_train: 0.8033
# Epoch 4: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.8555 - metric_choose_argument_counter_y_train: 0.7812 - val_loss: -0.9340 - val_metric_choose_argument_counter_y_train: 0.7031
# Epoch 5/20
# 60/64 [===========================>..] - ETA: 0s - loss: -0.9338 - metric_choose_argument_counter_y_train: 0.7833
# Epoch 5: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 1s 8ms/step - loss: -0.9338 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.9704 - val_metric_choose_argument_counter_y_train: 0.6562
# Epoch 6/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9694 - metric_choose_argument_counter_y_train: 0.7869
# Epoch 6: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.9693 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.9848 - val_metric_choose_argument_counter_y_train: 0.6719
# Epoch 7/20
# 60/64 [===========================>..] - ETA: 0s - loss: -0.9826 - metric_choose_argument_counter_y_train: 0.8833
# Epoch 7: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.9823 - metric_choose_argument_counter_y_train: 0.8750 - val_loss: -0.9887 - val_metric_choose_argument_counter_y_train: 0.7812
# Epoch 8/20
# 59/64 [==========================>...] - ETA: 0s - loss: -0.9880 - metric_choose_argument_counter_y_train: 0.7797
# Epoch 8: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.9880 - metric_choose_argument_counter_y_train: 0.7812 - val_loss: -0.9902 - val_metric_choose_argument_counter_y_train: 0.6875
# Epoch 9/20
# 60/64 [===========================>..] - ETA: 0s - loss: -0.9895 - metric_choose_argument_counter_y_train: 0.8667
# Epoch 9: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.9897 - metric_choose_argument_counter_y_train: 0.8750 - val_loss: -0.9922 - val_metric_choose_argument_counter_y_train: 0.8125
# Epoch 10/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9913 - metric_choose_argument_counter_y_train: 0.7705
# Epoch 10: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.9912 - metric_choose_argument_counter_y_train: 0.7812 - val_loss: -0.9928 - val_metric_choose_argument_counter_y_train: 0.7031
# Epoch 11/20
# 62/64 [============================>.] - ETA: 0s - loss: -0.9915 - metric_choose_argument_counter_y_train: 0.8065
# Epoch 11: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 7ms/step - loss: -0.9915 - metric_choose_argument_counter_y_train: 0.8125 - val_loss: -0.9923 - val_metric_choose_argument_counter_y_train: 0.7500
# Epoch 12/20
# 57/64 [=========================>....] - ETA: 0s - loss: -0.9917 - metric_choose_argument_counter_y_train: 0.8246
# Epoch 12: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 1s 8ms/step - loss: -0.9917 - metric_choose_argument_counter_y_train: 0.8281 - val_loss: -0.9921 - val_metric_choose_argument_counter_y_train: 0.7500
# Epoch 13/20
# 62/64 [============================>.] - ETA: 0s - loss: -0.9907 - metric_choose_argument_counter_y_train: 0.7742
# Epoch 13: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 7ms/step - loss: -0.9907 - metric_choose_argument_counter_y_train: 0.7812 - val_loss: -0.9911 - val_metric_choose_argument_counter_y_train: 0.7031
# Epoch 14/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9898 - metric_choose_argument_counter_y_train: 0.8197
# Epoch 14: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 1s 8ms/step - loss: -0.9899 - metric_choose_argument_counter_y_train: 0.8125 - val_loss: -0.9910 - val_metric_choose_argument_counter_y_train: 0.7500
# Epoch 15/20
# 62/64 [============================>.] - ETA: 0s - loss: -0.9895 - metric_choose_argument_counter_y_train: 0.7742
# Epoch 15: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 7ms/step - loss: -0.9894 - metric_choose_argument_counter_y_train: 0.7812 - val_loss: -0.9911 - val_metric_choose_argument_counter_y_train: 0.7031
# Epoch 16/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9902 - metric_choose_argument_counter_y_train: 0.7869
# Epoch 16: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 1s 8ms/step - loss: -0.9901 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.9913 - val_metric_choose_argument_counter_y_train: 0.7656
# Epoch 17/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9901 - metric_choose_argument_counter_y_train: 0.8033
# Epoch 17: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 7ms/step - loss: -0.9903 - metric_choose_argument_counter_y_train: 0.8125 - val_loss: -0.9918 - val_metric_choose_argument_counter_y_train: 0.7031
# Epoch 18/20
# 62/64 [============================>.] - ETA: 0s - loss: -0.9914 - metric_choose_argument_counter_y_train: 0.7903
# Epoch 18: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 8ms/step - loss: -0.9914 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.9936 - val_metric_choose_argument_counter_y_train: 0.7656
# Epoch 19/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9927 - metric_choose_argument_counter_y_train: 0.7869
# Epoch 19: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 7ms/step - loss: -0.9927 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.9942 - val_metric_choose_argument_counter_y_train: 0.7031
# Epoch 20/20
# 61/64 [===========================>..] - ETA: 0s - loss: -0.9936 - metric_choose_argument_counter_y_train: 0.8525
# Epoch 20: saving model to counter_autoencoder_weights.keras
# 64/64 [==============================] - 0s 7ms/step - loss: -0.9936 - metric_choose_argument_counter_y_train: 0.8281 - val_loss: -0.9949 - val_metric_choose_argument_counter_y_train: 0.7500

# %%
counter_history_df = pd.DataFrame(counter_history.history)

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
counter_history_df.to_csv(f'{output_folder_path}counter_training_log.csv')

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
counter_autoencoder_model.save(f'{output_folder_path}counter_autoencoder_model.keras')

# %% [markdown]
# ### Counter Shuffled Training

# %%
# counter Shuffled Model
counter_shuffled_autoencoder_model = tf.keras.models.clone_model(autoencoder_model)
counter_shuffled_autoencoder_model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_counter_y_train]
)

counter_shuffled_history = counter_shuffled_autoencoder_model.fit(
  x=x_train_counter,
  y=y_train_counter_shuffled,
  batch_size=1,
  epochs=20,
  validation_data = (x_test_counter, y_test_counter)
)
# Out:
# Epoch 1/20
# 64/64 [==============================] - 1s 8ms/step - loss: -0.4196 - metric_choose_argument_counter_y_train: 0.0000e+00 - val_loss: -0.4950 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 2/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.5332 - metric_choose_argument_counter_y_train: 0.0469 - val_loss: -0.4583 - val_metric_choose_argument_counter_y_train: 0.0156
# Epoch 3/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.6647 - metric_choose_argument_counter_y_train: 0.5625 - val_loss: -0.3512 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 4/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.8033 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.2700 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 5/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9063 - metric_choose_argument_counter_y_train: 0.8281 - val_loss: -0.2572 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 6/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9553 - metric_choose_argument_counter_y_train: 0.8281 - val_loss: -0.2463 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 7/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9755 - metric_choose_argument_counter_y_train: 0.8438 - val_loss: -0.2440 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 8/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9834 - metric_choose_argument_counter_y_train: 0.7188 - val_loss: -0.2461 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 9/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9824 - metric_choose_argument_counter_y_train: 0.8750 - val_loss: -0.2459 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 10/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9900 - metric_choose_argument_counter_y_train: 0.7344 - val_loss: -0.2384 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 11/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9912 - metric_choose_argument_counter_y_train: 0.8594 - val_loss: -0.2434 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 12/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9916 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.2404 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 13/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9919 - metric_choose_argument_counter_y_train: 0.7969 - val_loss: -0.2419 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 14/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9917 - metric_choose_argument_counter_y_train: 0.8438 - val_loss: -0.2429 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 15/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9921 - metric_choose_argument_counter_y_train: 0.7812 - val_loss: -0.2331 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 16/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9917 - metric_choose_argument_counter_y_train: 0.8125 - val_loss: -0.2424 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 17/20
# 64/64 [==============================] - 0s 5ms/step - loss: -0.9916 - metric_choose_argument_counter_y_train: 0.8125 - val_loss: -0.2455 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 18/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9912 - metric_choose_argument_counter_y_train: 0.8438 - val_loss: -0.2483 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 19/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9916 - metric_choose_argument_counter_y_train: 0.8281 - val_loss: -0.2395 - val_metric_choose_argument_counter_y_train: 0.0000e+00
# Epoch 20/20
# 64/64 [==============================] - 0s 4ms/step - loss: -0.9916 - metric_choose_argument_counter_y_train: 0.8750 - val_loss: -0.2406 - val_metric_choose_argument_counter_y_train: 0.0000e+00

# %%
counter_shuffled_history_df = pd.DataFrame(counter_shuffled_history.history)

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
counter_shuffled_history_df.to_csv(f'{output_folder_path}counter_shuffled_training_log.csv')

# %%
output_folder_path = 'current-data-dump/ada003-autoencoder/'
os.makedirs(output_folder_path, exist_ok=True)
counter_shuffled_autoencoder_model.save(f'{output_folder_path}counter_shuffled_autoencoder_model.keras')

# %% [markdown]
# ## Export data

# %%
def export_ada_autoencoder():
  """Export ada_autoencoder directory"""
  ada_autoencoder_file_path = 'current-data-dump/ada003-autoencoder'
  ada_autoencoder_file_path_zip = 'current-data-dump/ada003-autoencoder'
  shutil.make_archive(ada_autoencoder_file_path_zip, 'zip', ada_autoencoder_file_path)
  print(f"Zip file created at: {ada_autoencoder_file_path_zip}")
  result = subprocess.run([f"osf -p sakjg upload --force {ada_autoencoder_file_path_zip}.zip data-dump/ada003-scifact-autoencoder/ada003_scifact_autoencoder.zip"], shell=True, capture_output=True, text=True)
  print(result.stderr)
  print(f"File: {ada_autoencoder_file_path_zip} uploaded at osfstorage")

# %%
export_ada_autoencoder()
# Out:
# Zip file created at: current-data-dump/ada003-autoencoder
#
# File: current-data-dump/ada003-autoencoder uploaded at osfstorage

# %% [markdown]
# ## Import data

# %%
def import_ada_autoencoder():
  """Import ada_autoencoder directory"""
  subprocess.run("osf -p sakjg fetch --force osfstorage/data-dump/ada003-scifact-autoencoder/ada003_scifact_autoencoder.zip", shell=True)
  print("ada_autoencoder.zip successfully imported")
  ada_autoencoder_file_path_zip = 'ada003_scifact_autoencoder.zip'
  ada_autoencoder_file_path = 'current-data-dump/ada003-autoencoder'
  os.makedirs(ada_autoencoder_file_path, exist_ok=True)
  with zipfile.ZipFile(ada_autoencoder_file_path_zip, 'r') as zip_ref:
    zip_ref.extractall(ada_autoencoder_file_path)
  extracted_files = os.listdir(ada_autoencoder_file_path)
  print("Files extracted:", extracted_files)

# %% [markdown]
# ## Load global training history

# %%
import_ada_autoencoder()
# Out:
# ada_autoencoder.zip successfully imported
# Files extracted: ['combined_shuffled_training_log.csv', 'pro_training_log.csv', 'counter_training_log.csv', 'counter_training_plot.png', 'x_test_pro.pkl', 'all_shuffled_training_plot.png', 'y_train_combined.pkl', 'counter_shuffled_training_log.csv', 'pro_shuffled_training_plot.png', 'y_test_combined.pkl', 'y_test_pro.pkl', 'pro_shuffled_autoencoder_model.keras', 'combined_autoencoder_model.keras', 'pro_training_plot.png', 'y_train_counter.pkl', 'y_test_counter.pkl', 'y_train_pro.pkl', 'combined_counter_training_plot.png', 'x_train_combined.pkl', 'combined_training_plot.png', 'x_train_counter.pkl', 'counter_shuffled_autoencoder_model.keras', 'x_test_combined.pkl', 'combined_pro_training_plot.png', 'counter_shuffled_training_plot.png', 'counter_autoencoder_model.keras', 'x_test_counter.pkl', 'pro_autoencoder_model.keras', 'combined_shuffled_autoencoder_model.keras', 'all_training_plot.png', 'combined_training_log.csv', 'x_train_pro.pkl', 'pro_shuffled_training_log.csv']

# %% [markdown]
# #### Unshuffled training history

# %%
# Access training history
loaded_combined_history = pd.DataFrame(pd.read_csv("current-data-dump/ada003-autoencoder/combined_training_log.csv"))
loaded_combined_history = pd.melt(loaded_combined_history, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_combined_y_train', 'val_metric_choose_argument_combined_y_train'], var_name='dataset', value_name='accuracy')
loaded_combined_history = loaded_combined_history.replace(['metric_choose_argument_combined_y_train', 'val_metric_choose_argument_combined_y_train'], ['training set', 'validation set'])
loaded_combined_history.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
loaded_combined_history['shuffled'] = False

loaded_pro_history = pd.DataFrame(pd.read_csv("current-data-dump/ada003-autoencoder/pro_training_log.csv"))
loaded_pro_history = pd.melt(loaded_pro_history, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_pro_y_train', 'val_metric_choose_argument_pro_y_train'], var_name='dataset', value_name='accuracy')
loaded_pro_history = loaded_pro_history.replace(['metric_choose_argument_pro_y_train', 'val_metric_choose_argument_pro_y_train'], ['training set', 'validation set'])
loaded_pro_history.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
loaded_pro_history['shuffled'] = False

loaded_counter_history = pd.DataFrame(pd.read_csv("current-data-dump/ada003-autoencoder/counter_training_log.csv"))
loaded_counter_history = pd.melt(loaded_counter_history, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_counter_y_train', 'val_metric_choose_argument_counter_y_train'], var_name='dataset', value_name='accuracy')
loaded_counter_history = loaded_counter_history.replace(['metric_choose_argument_counter_y_train', 'val_metric_choose_argument_counter_y_train'], ['training set', 'validation set'])
loaded_counter_history.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
loaded_counter_history['shuffled'] = False

# %%
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

all_training_plot = (
    ggplot(loaded_combined_history, aes(x='epoch', y='accuracy', linetype='dataset')) +
    geom_line(size=2) +
    labs(title='Learning Curve of Model Trained on Unshuffled Data', x='Epoch', y='Accuracy') +
    scale_y_continuous(limits=[0,1]) +
    scale_linetype_manual(linetype_map) +
    theme(
        plot_title=element_text(size=40, lineheight=1.5, wrap=True),
        axis_title=element_text(size=32),
        axis_text=element_text(size=24),
        legend_position='bottom',
        legend_text=element_text(size=24),
        legend_title=element_text(size=32),
        figure_size=[16,24]
        )
)
ggsave(all_training_plot, "current-data-dump/ada003-autoencoder/all_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/all_training_plot.png

# %%
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

pro_training_plot = (
    ggplot(loaded_combined_history, aes(x='epoch', y='accuracy', linetype='dataset')) +
    geom_line(size=2) +
    labs(title='Learning Curve of Model Trained on Unshuffled Data (Pro-Evidence Only)', x='Epoch', y='Accuracy') +
    scale_y_continuous(limits=[0,1]) +
    scale_linetype_manual(linetype_map) +
    theme(
        plot_title=element_text(size=40, lineheight=1.5, wrap=True),
        axis_title=element_text(size=32),
        axis_text=element_text(size=24),
        legend_position='bottom',
        legend_text=element_text(size=24),
        legend_title=element_text(size=32),
        figure_size=[16,24]
        )
)
ggsave(pro_training_plot, "current-data-dump/ada003-autoencoder/pro_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/pro_training_plot.png

# %%
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

counter_training_plot = (
    ggplot(loaded_combined_history, aes(x='epoch', y='accuracy', linetype='dataset')) +
    geom_line(size=2) +
    labs(title='Learning Curve of Model Trained on Unshuffled Data (Counterevidence Only)', x='Epoch', y='Accuracy') +
    scale_y_continuous(limits=[0,1]) +
    scale_linetype_manual(linetype_map) +
    theme(
        plot_title=element_text(size=40, lineheight=1.5, wrap=True),
        axis_title=element_text(size=32),
        axis_text=element_text(size=24),
        legend_position='bottom',
        legend_text=element_text(size=24),
        legend_title=element_text(size=32),
        figure_size=[16,24]
        )
)
ggsave(counter_training_plot, "current-data-dump/ada003-autoencoder/counter_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/counter_training_plot.png

# %% [markdown]
# #### Shuffled training history

# %%
# Access training history
loaded_combined_shuffled_history = pd.DataFrame(pd.read_csv("current-data-dump/ada003-autoencoder/combined_shuffled_training_log.csv"))
loaded_combined_shuffled_history = pd.melt(loaded_combined_shuffled_history, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_combined_y_train', 'val_metric_choose_argument_combined_y_train'], var_name='dataset', value_name='accuracy')
loaded_combined_shuffled_history = loaded_combined_shuffled_history.replace(['metric_choose_argument_combined_y_train', 'val_metric_choose_argument_combined_y_train'], ['training set', 'validation set'])
loaded_combined_shuffled_history.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
loaded_combined_shuffled_history['shuffled'] = True

loaded_pro_shuffled_history = pd.DataFrame(pd.read_csv("current-data-dump/ada003-autoencoder/pro_shuffled_training_log.csv"))
loaded_pro_shuffled_history = pd.melt(loaded_pro_shuffled_history, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_pro_y_train', 'val_metric_choose_argument_pro_y_train'], var_name='dataset', value_name='accuracy')
loaded_pro_shuffled_history = loaded_pro_shuffled_history.replace(['metric_choose_argument_pro_y_train', 'val_metric_choose_argument_pro_y_train'], ['training set', 'validation set'])
loaded_pro_shuffled_history.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
loaded_pro_shuffled_history['shuffled'] = True

loaded_counter_shuffled_history = pd.DataFrame(pd.read_csv("current-data-dump/ada003-autoencoder/counter_shuffled_training_log.csv"))
loaded_counter_shuffled_history = pd.melt(loaded_counter_shuffled_history, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_counter_y_train', 'val_metric_choose_argument_counter_y_train'], var_name='dataset', value_name='accuracy')
loaded_counter_shuffled_history = loaded_counter_shuffled_history.replace(['metric_choose_argument_counter_y_train', 'val_metric_choose_argument_counter_y_train'], ['training set', 'validation set'])
loaded_counter_shuffled_history.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
loaded_counter_shuffled_history['shuffled'] = True

# %%
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

all_shuffled_training_plot = (
    ggplot(loaded_combined_shuffled_history, aes(x='epoch', y='accuracy', linetype='dataset')) +
    geom_line(size=2) +
    labs(title='Learning Curve of Model Trained on Shuffled Data', x='Epoch', y='Accuracy') +
    scale_y_continuous(limits=[0,1]) +
    scale_linetype_manual(linetype_map) +
    theme(
        plot_title=element_text(size=40, lineheight=1.5, wrap=True),
        axis_title=element_text(size=32),
        axis_text=element_text(size=24),
        legend_position='bottom',
        legend_text=element_text(size=24),
        legend_title=element_text(size=32),
        figure_size=[16,24]
        )
)
ggsave(all_shuffled_training_plot, "current-data-dump/ada003-autoencoder/all_shuffled_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/all_shuffled_training_plot.png

# %%
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

pro_shuffled_training_plot = (
    ggplot(loaded_combined_shuffled_history, aes(x='epoch', y='accuracy', linetype='dataset')) +
    geom_line(size=2) +
    labs(title='Learning Curve of Model Trained on Shuffled Data (Pro-evidence Only)', x='Epoch', y='Accuracy') +
    scale_y_continuous(limits=[0,1]) +
    scale_linetype_manual(linetype_map) +
    theme(
        plot_title=element_text(size=40, lineheight=1.5, wrap=True),
        axis_title=element_text(size=32),
        axis_text=element_text(size=24),
        legend_position='bottom',
        legend_text=element_text(size=24),
        legend_title=element_text(size=32),
        figure_size=[16,24]
        )
)
ggsave(pro_shuffled_training_plot, "current-data-dump/ada003-autoencoder/pro_shuffled_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/pro_shuffled_training_plot.png

# %%
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

counter_shuffled_training_plot = (
    ggplot(loaded_combined_shuffled_history, aes(x='epoch', y='accuracy', linetype='dataset')) +
    geom_line(size=2) +
    labs(title='Learning Curve of Model Trained on Shuffled Data (Counterevidence only)', x='Epoch', y='Accuracy') +
    scale_y_continuous(limits=[0,1]) +
    scale_linetype_manual(linetype_map) +
    theme(
        plot_title=element_text(size=40, lineheight=1.5, wrap=True),
        axis_title=element_text(size=32),
        axis_text=element_text(size=24),
        legend_position='bottom',
        legend_text=element_text(size=24),
        legend_title=element_text(size=32),
        figure_size=[16,24]
        )
)
ggsave(counter_shuffled_training_plot, "current-data-dump/ada003-autoencoder/counter_shuffled_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/counter_shuffled_training_plot.png

# %% [markdown]
# ## Combined Training Plots

# %%
combined_training_df = pd.concat([loaded_combined_history, loaded_combined_shuffled_history])
combined_pro_training_df = pd.concat([loaded_pro_history, loaded_pro_shuffled_history])
combined_counter_training_df = pd.concat([loaded_counter_history, loaded_counter_shuffled_history])

# %%
linetype_map={'validation set': 'solid', 'training set': 'dashed'}

combined_plot = (
  ggplot(combined_training_df, aes(x='epoch', y='accuracy', linetype='dataset', color='shuffled')) +
  geom_line(size=2) +
  labs(title='Learning Curve of Model Trained on Unshuffled vs. Within-Topic Shuffled Data', x='Epoch', y='Accuracy') +
  scale_linetype_manual(linetype_map) +
  theme(
    figure_size=(16,24),
    axis_title=element_text(size=32),
    axis_text=element_text(size=24),
    legend_title=element_text(size=32, lineheight=1.5),
    legend_text=element_text(size=24, lineheight=1.5),
    plot_title=element_text(size=40, wrap=True, lineheight=1.5),
    legend_position="bottom",
    legend_key_width=64
  ) +
  guides(fill = guide_legend(byrow = True))
)
ggsave(combined_plot, "current-data-dump/ada003-autoencoder/combined_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/combined_training_plot.png

# %%
linetype_map={'validation set': 'solid', 'training set': 'dashed'}

combined_pro_plot = (
  ggplot(combined_pro_training_df, aes(x='epoch', y='accuracy', linetype='dataset', color='shuffled')) +
  geom_line(size=2) +
  labs(title='Learning Curve of Model Trained on Unshuffled vs. Within-Topic Shuffled Data (Pro-evidence Only)', x='Epoch', y='Accuracy') +
  scale_linetype_manual(linetype_map) +
  theme(
    figure_size=(16,24),
    axis_title=element_text(size=32),
    axis_text=element_text(size=24),
    legend_title=element_text(size=32, lineheight=1.5),
    legend_text=element_text(size=24, lineheight=1.5),
    plot_title=element_text(size=40, wrap=True, lineheight=1.5),
    legend_position="bottom",
    legend_key_width=64
  ) +
  guides(fill = guide_legend(byrow = True))
)
ggsave(combined_pro_plot, "current-data-dump/ada003-autoencoder/combined_pro_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/combined_pro_training_plot.png

# %%
linetype_map={'validation set': 'solid', 'training set': 'dashed'}

combined_counter_plot = (
  ggplot(combined_counter_training_df, aes(x='epoch', y='accuracy', linetype='dataset', color='shuffled')) +
  geom_line(size=2) +
  labs(title='Learning Curve of Model Trained on Unshuffled vs. Within-Topic Shuffled Data (Counterevidence Only)', x='Epoch', y='Accuracy') +
  scale_linetype_manual(linetype_map) +
  theme(
    figure_size=(16,24),
    axis_title=element_text(size=32),
    axis_text=element_text(size=24),
    legend_title=element_text(size=32, lineheight=1.5),
    legend_text=element_text(size=24, lineheight=1.5),
    plot_title=element_text(size=40, wrap=True, lineheight=1.5),
    legend_position="bottom",
    legend_key_width=64
  ) +
  guides(fill = guide_legend(byrow = True))
)
ggsave(combined_counter_plot, "current-data-dump/ada003-autoencoder/combined_counter_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/ada003-autoencoder/combined_counter_training_plot.png

# %%
combined_counter_plot
# Out:
# <Figure Size: (1600 x 2400)>

# %% [markdown]
# ## Final Export

# %%
export_ada_autoencoder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-bb8525cb86ef> in <cell line: 1>()
# ----> 1 export_ada_autoencoder()
#
# NameError: name 'export_ada_autoencoder' is not defined
