# %% [markdown]
# <a href="https://colab.research.google.com/github/cchang-vassar/Semantic-Relations-in-Vector-Embeddings/blob/main/study2_18_%5Bnomic_scifact%5Ddiff_model_architectures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [nomic-scifact] more layers

# %% [markdown]
# Try 2 new architectures:
#
#
# 1.   2 hidden layers: 1536*2 -> 1536
# 2.   3 hidden layers: 1536\*4 -> 1536\*2 -> 1536

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Imports

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import os
import subprocess
import zipfile
import shutil
import pickle
import tensorflow as tf
import pandas as pd
import numpy as np
from google.colab import userdata
from scipy import spatial
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from plotnine import ggplot, geom_line, aes, ggsave, labs, theme, element_text, guides, guide_legend, scale_color_manual, scale_linetype_manual

# %% [markdown]
# ### OSF Setup

# %%
# !pip install osfclient
# Out:
# Collecting osfclient
#   Downloading osfclient-0.0.5-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from osfclient) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from osfclient) (4.66.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from osfclient) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (2024.2.2)
# Installing collected packages: osfclient
# Successfully installed osfclient-0.0.5

# %%
import osfclient.cli

# %%
from osfclient.api import OSF
from osfclient.models import Project, Storage
from io import BytesIO

# %%
os.environ["OSF_USERNAME"] = userdata.get("OSF_USERNAME")
OSF_USERNAME = os.environ["OSF_USERNAME"]

# %%
os.environ["OSF_PASSWORD"] = userdata.get("OSF_PASSWORD")
OSF_PASSWORD = os.environ["OSF_PASSWORD"]

# %%
os.environ["OSF_TOKEN"] = userdata.get("OSF_TOKEN")
OSF_TOKEN = os.environ["OSF_TOKEN"]

# %%
os.environ["OSF_PROJECT_ID"] = userdata.get("OSF_PROJECT_ID")
OSF_PROJECT_ID = os.environ["OSF_PROJECT_ID"]

# %% [markdown]
# ## Data

# %% [markdown]
# ### Import training data from OSF

# %%
# !osf -p sakjg fetch osfstorage/data-dump/nomic-scifact-autoencoder/nomic_scifact_autoencoder.zip
# Out:
# 100% 87.4M/87.4M [00:02<00:00, 40.9Mbytes/s]

# %%
# !osf -p sakjg fetch osfstorage/data-dump/nomic-autoencoder/nomic_scifact_embeddings_dump.zip
# Out:
# 100% 7.96M/7.96M [00:00<00:00, 72.4Mbytes/s]

# %%
nomic_autoencoder_file_path = 'nomic_scifact_autoencoder.zip'
output_folder_path = 'current-data-dump/nomic-autoencoder'
os.makedirs(output_folder_path, exist_ok=True)

with zipfile.ZipFile(nomic_autoencoder_file_path, 'r') as zip_ref:
  zip_ref.extractall(output_folder_path)

extracted_files = os.listdir(output_folder_path)
print("Files extracted:", extracted_files)
# Out:
# Files extracted: ['y_train_combined.pkl', 'combined_training_log.csv', 'combined_shuffled_training_log.csv', 'counter_shuffled_autoencoder_model.keras', 'pro_autoencoder_model.keras', 'all_pro_training_plot.png', 'counter_shuffled_training_plot.png', 'y_test_counter.pkl', 'all_counter_training_plot.png', 'pro_shuffled_training_log.csv', 'pro_shuffled_autoencoder_model.keras', 'x_train_pro.pkl', 'pro_training_log.csv', 'x_test_combined.pkl', 'counter_training_plot.png', 'x_test_pro.pkl', 'combined_shuffled_training_plot.png', 'all_combined_training_plot.png', 'pro_shuffled_training_plot.png', 'x_train_combined.pkl', 'y_test_combined.pkl', 'x_test_counter.pkl', 'y_test_pro.pkl', 'counter_training_log.csv', 'counter_shuffled_training_log.csv', 'combined_autoencoder_model.keras', 'combined_shuffled_autoencoder_model.keras', 'y_train_counter.pkl', 'y_train_pro.pkl', 'combined_training_plot.png', 'counter_autoencoder_model.keras', 'pro_training_plot.png', 'x_train_counter.pkl']

# %%
nomic_embeddings_file_path = 'nomic_scifact_embeddings_dump.zip'
output_folder_path = 'current-data-dump/embeddings-dump'
os.makedirs(output_folder_path, exist_ok=True)

with zipfile.ZipFile(nomic_embeddings_file_path, 'r') as zip_ref:
  zip_ref.extractall(output_folder_path)

extracted_files = os.listdir(output_folder_path)
print("Files extracted:", extracted_files)
# Out:
# Files extracted: ['training_pro_argument_embeddings.pkl', 'combined_counter_evidence_embeddings.pkl', 'training_pro_evidence_embeddings.pkl', 'combined_pro_argument_embeddings.pkl', 'test_counter_evidence_embeddings.pkl', 'training_counter_argument_embeddings.pkl', 'test_counter_argument_embeddings.pkl', 'combined_counter_argument_embeddings.pkl', 'combined_pro_evidence_embeddings.pkl', 'test_pro_evidence_embeddings.pkl', 'test_pro_argument_embeddings.pkl', 'training_counter_evidence_embeddings.pkl']

# %%
x_train = pd.read_pickle('current-data-dump/nomic-autoencoder/x_train_combined.pkl')
y_train = pd.read_pickle('current-data-dump/nomic-autoencoder/y_train_combined.pkl')
x_test = pd.read_pickle('current-data-dump/nomic-autoencoder/x_test_combined.pkl')
y_test = pd.read_pickle('current-data-dump/nomic-autoencoder/y_test_combined.pkl')

# %% [markdown]
# ## Metric

# %%
@tf.keras.saving.register_keras_serializable()
def metric_choose_argument_global_y_train(y_true, y_pred):
  """global_metric"""
  global_training_df_32 = tf.cast(pd.concat([x_train, y_train, x_test, y_test]), dtype=tf.float32)

  cos_sim_pred = tf.matmul(global_training_df_32, y_pred, transpose_b=True) / tf.reshape(tf.norm(y_pred) * tf.norm(global_training_df_32, axis=1), [-1, 1])
  cos_sim_true = tf.matmul(global_training_df_32, y_true, transpose_b=True) / tf.reshape(tf.norm(y_true) * tf.norm(global_training_df_32, axis=1), [-1, 1])

  max_cos_sim_pred = tf.math.argmax(cos_sim_pred)
  max_cos_sim_true = tf.math.argmax(cos_sim_true)

  return tf.math.count_nonzero(tf.equal(max_cos_sim_pred, max_cos_sim_true))

# %% [markdown]
# ## 2-layer model

# %% [markdown]
# ### 2-layer architecture

# %%
# Layers
input_layer = tf.keras.layers.Input(shape=(768, ), name="Input")
hidden_layer_1 = tf.keras.layers.Dense(units=768*2, activation="relu", name="Hidden1")(input_layer)
hidden_layer_2 = tf.keras.layers.Dense(units=768, activation="relu", name="Hidden2")(hidden_layer_1)
output_layer = tf.keras.layers.Dense(units=768, activation="linear", name="Output")(hidden_layer_2)

# %%
# Model
autoencoder_model_2_layer = tf.keras.Model(inputs=input_layer, outputs=output_layer)
autoencoder_model_2_layer.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 768)]             0
#
#  Hidden1 (Dense)             (None, 1536)              1181184
#
#  Hidden2 (Dense)             (None, 768)               1180416
#
#  Output (Dense)              (None, 768)               590592
#
# =================================================================
# Total params: 2952192 (11.26 MB)
# Trainable params: 2952192 (11.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Global Training

# %%
# Global Model
global_autoencoder_model_2_layer = autoencoder_model_2_layer
global_autoencoder_model_2_layer.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_global_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='global_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='global_training_log.csv', separator=',', append=True)
global_history_2_layer = global_autoencoder_model_2_layer.fit(
  x=x_train,
  y=y_train,
  batch_size=1,
  epochs=100,
  validation_data = (x_test, y_test),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.7758 - metric_choose_argument_global_y_train: 0.0060
# Epoch 1: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 8s 5ms/step - loss: -0.7759 - metric_choose_argument_global_y_train: 0.0059 - val_loss: -0.7918 - val_metric_choose_argument_global_y_train: 0.0053
# Epoch 2/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.8020 - metric_choose_argument_global_y_train: 0.0243
# Epoch 2: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.8023 - metric_choose_argument_global_y_train: 0.0238 - val_loss: -0.8031 - val_metric_choose_argument_global_y_train: 0.0213
# Epoch 3/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.8202 - metric_choose_argument_global_y_train: 0.0789
# Epoch 3: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.8204 - metric_choose_argument_global_y_train: 0.0792 - val_loss: -0.8126 - val_metric_choose_argument_global_y_train: 0.0585
# Epoch 4/100
# 489/505 [============================>.] - ETA: 0s - loss: -0.8402 - metric_choose_argument_global_y_train: 0.2352
# Epoch 4: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.8397 - metric_choose_argument_global_y_train: 0.2297 - val_loss: -0.8217 - val_metric_choose_argument_global_y_train: 0.1170
# Epoch 5/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.8593 - metric_choose_argument_global_y_train: 0.3772
# Epoch 5: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.8592 - metric_choose_argument_global_y_train: 0.3743 - val_loss: -0.8290 - val_metric_choose_argument_global_y_train: 0.1968
# Epoch 6/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.8771 - metric_choose_argument_global_y_train: 0.5302
# Epoch 6: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 5ms/step - loss: -0.8769 - metric_choose_argument_global_y_train: 0.5287 - val_loss: -0.8330 - val_metric_choose_argument_global_y_train: 0.2340
# Epoch 7/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.8954 - metric_choose_argument_global_y_train: 0.6389
# Epoch 7: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.8956 - metric_choose_argument_global_y_train: 0.6396 - val_loss: -0.8387 - val_metric_choose_argument_global_y_train: 0.2606
# Epoch 8/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9097 - metric_choose_argument_global_y_train: 0.7227
# Epoch 8: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9098 - metric_choose_argument_global_y_train: 0.7228 - val_loss: -0.8406 - val_metric_choose_argument_global_y_train: 0.2819
# Epoch 9/100
# 490/505 [============================>.] - ETA: 0s - loss: -0.9225 - metric_choose_argument_global_y_train: 0.7673
# Epoch 9: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9219 - metric_choose_argument_global_y_train: 0.7663 - val_loss: -0.8437 - val_metric_choose_argument_global_y_train: 0.2766
# Epoch 10/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9328 - metric_choose_argument_global_y_train: 0.8263
# Epoch 10: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9327 - metric_choose_argument_global_y_train: 0.8238 - val_loss: -0.8469 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 11/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9411 - metric_choose_argument_global_y_train: 0.8270
# Epoch 11: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9410 - metric_choose_argument_global_y_train: 0.8257 - val_loss: -0.8504 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 12/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9481 - metric_choose_argument_global_y_train: 0.8508
# Epoch 12: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9480 - metric_choose_argument_global_y_train: 0.8495 - val_loss: -0.8497 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 13/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9536 - metric_choose_argument_global_y_train: 0.8511
# Epoch 13: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9536 - metric_choose_argument_global_y_train: 0.8535 - val_loss: -0.8462 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 14/100
# 491/505 [============================>.] - ETA: 0s - loss: -0.9586 - metric_choose_argument_global_y_train: 0.8493
# Epoch 14: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9584 - metric_choose_argument_global_y_train: 0.8436 - val_loss: -0.8528 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 15/100
# 492/505 [============================>.] - ETA: 0s - loss: -0.9621 - metric_choose_argument_global_y_train: 0.8577
# Epoch 15: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9621 - metric_choose_argument_global_y_train: 0.8574 - val_loss: -0.8521 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 16/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9658 - metric_choose_argument_global_y_train: 0.8643
# Epoch 16: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 5ms/step - loss: -0.9655 - metric_choose_argument_global_y_train: 0.8614 - val_loss: -0.8551 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 17/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9685 - metric_choose_argument_global_y_train: 0.8704
# Epoch 17: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9686 - metric_choose_argument_global_y_train: 0.8673 - val_loss: -0.8549 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 18/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9701 - metric_choose_argument_global_y_train: 0.8860
# Epoch 18: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9700 - metric_choose_argument_global_y_train: 0.8832 - val_loss: -0.8540 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 19/100
# 488/505 [===========================>..] - ETA: 0s - loss: -0.9727 - metric_choose_argument_global_y_train: 0.8730
# Epoch 19: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9725 - metric_choose_argument_global_y_train: 0.8733 - val_loss: -0.8559 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 20/100
# 493/505 [============================>.] - ETA: 0s - loss: -0.9748 - metric_choose_argument_global_y_train: 0.8722
# Epoch 20: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9748 - metric_choose_argument_global_y_train: 0.8733 - val_loss: -0.8536 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 21/100
# 487/505 [===========================>..] - ETA: 0s - loss: -0.9770 - metric_choose_argument_global_y_train: 0.9014
# Epoch 21: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9765 - metric_choose_argument_global_y_train: 0.8891 - val_loss: -0.8546 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 22/100
# 489/505 [============================>.] - ETA: 0s - loss: -0.9776 - metric_choose_argument_global_y_train: 0.8834
# Epoch 22: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9775 - metric_choose_argument_global_y_train: 0.8812 - val_loss: -0.8549 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 23/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9788 - metric_choose_argument_global_y_train: 0.8880
# Epoch 23: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 5ms/step - loss: -0.9789 - metric_choose_argument_global_y_train: 0.8891 - val_loss: -0.8549 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 24/100
# 488/505 [===========================>..] - ETA: 0s - loss: -0.9799 - metric_choose_argument_global_y_train: 0.8914
# Epoch 24: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9797 - metric_choose_argument_global_y_train: 0.8891 - val_loss: -0.8532 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 25/100
# 491/505 [============================>.] - ETA: 0s - loss: -0.9800 - metric_choose_argument_global_y_train: 0.8819
# Epoch 25: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9800 - metric_choose_argument_global_y_train: 0.8832 - val_loss: -0.8530 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 26/100
# 492/505 [============================>.] - ETA: 0s - loss: -0.9816 - metric_choose_argument_global_y_train: 0.9024
# Epoch 26: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9816 - metric_choose_argument_global_y_train: 0.9010 - val_loss: -0.8561 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 27/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9827 - metric_choose_argument_global_y_train: 0.9006
# Epoch 27: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9827 - metric_choose_argument_global_y_train: 0.9010 - val_loss: -0.8573 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 28/100
# 490/505 [============================>.] - ETA: 0s - loss: -0.9834 - metric_choose_argument_global_y_train: 0.9041
# Epoch 28: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9831 - metric_choose_argument_global_y_train: 0.9010 - val_loss: -0.8542 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 29/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9833 - metric_choose_argument_global_y_train: 0.9046
# Epoch 29: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9834 - metric_choose_argument_global_y_train: 0.9050 - val_loss: -0.8548 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 30/100
# 487/505 [===========================>..] - ETA: 0s - loss: -0.9839 - metric_choose_argument_global_y_train: 0.9076
# Epoch 30: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9839 - metric_choose_argument_global_y_train: 0.9089 - val_loss: -0.8566 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 31/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9847 - metric_choose_argument_global_y_train: 0.9180
# Epoch 31: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9845 - metric_choose_argument_global_y_train: 0.9168 - val_loss: -0.8553 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 32/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9854 - metric_choose_argument_global_y_train: 0.9130
# Epoch 32: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9854 - metric_choose_argument_global_y_train: 0.9129 - val_loss: -0.8565 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 33/100
# 490/505 [============================>.] - ETA: 0s - loss: -0.9860 - metric_choose_argument_global_y_train: 0.9102
# Epoch 33: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9860 - metric_choose_argument_global_y_train: 0.9069 - val_loss: -0.8574 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 34/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9865 - metric_choose_argument_global_y_train: 0.9228
# Epoch 34: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9865 - metric_choose_argument_global_y_train: 0.9228 - val_loss: -0.8555 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 35/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9862 - metric_choose_argument_global_y_train: 0.9211
# Epoch 35: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9864 - metric_choose_argument_global_y_train: 0.9228 - val_loss: -0.8585 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 36/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9872 - metric_choose_argument_global_y_train: 0.9192
# Epoch 36: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9870 - metric_choose_argument_global_y_train: 0.9168 - val_loss: -0.8569 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 37/100
# 491/505 [============================>.] - ETA: 0s - loss: -0.9872 - metric_choose_argument_global_y_train: 0.9084
# Epoch 37: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9874 - metric_choose_argument_global_y_train: 0.9109 - val_loss: -0.8553 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 38/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9879 - metric_choose_argument_global_y_train: 0.9232
# Epoch 38: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9877 - metric_choose_argument_global_y_train: 0.9228 - val_loss: -0.8592 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 39/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9885 - metric_choose_argument_global_y_train: 0.9347
# Epoch 39: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9885 - metric_choose_argument_global_y_train: 0.9347 - val_loss: -0.8558 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 40/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9886 - metric_choose_argument_global_y_train: 0.9365
# Epoch 40: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 5ms/step - loss: -0.9886 - metric_choose_argument_global_y_train: 0.9366 - val_loss: -0.8581 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 41/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9888 - metric_choose_argument_global_y_train: 0.9347
# Epoch 41: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9888 - metric_choose_argument_global_y_train: 0.9347 - val_loss: -0.8592 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 42/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9890 - metric_choose_argument_global_y_train: 0.9365
# Epoch 42: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9890 - metric_choose_argument_global_y_train: 0.9366 - val_loss: -0.8579 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 43/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9891 - metric_choose_argument_global_y_train: 0.9332
# Epoch 43: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9892 - metric_choose_argument_global_y_train: 0.9347 - val_loss: -0.8599 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 44/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9896 - metric_choose_argument_global_y_train: 0.9385
# Epoch 44: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9896 - metric_choose_argument_global_y_train: 0.9386 - val_loss: -0.8596 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 45/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9902 - metric_choose_argument_global_y_train: 0.9459
# Epoch 45: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 5ms/step - loss: -0.9902 - metric_choose_argument_global_y_train: 0.9465 - val_loss: -0.8585 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 46/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9900 - metric_choose_argument_global_y_train: 0.9438
# Epoch 46: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9900 - metric_choose_argument_global_y_train: 0.9446 - val_loss: -0.8604 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 47/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9901 - metric_choose_argument_global_y_train: 0.9505
# Epoch 47: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9901 - metric_choose_argument_global_y_train: 0.9505 - val_loss: -0.8593 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 48/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9906 - metric_choose_argument_global_y_train: 0.9582
# Epoch 48: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9906 - metric_choose_argument_global_y_train: 0.9584 - val_loss: -0.8581 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 49/100
# 489/505 [============================>.] - ETA: 0s - loss: -0.9908 - metric_choose_argument_global_y_train: 0.9509
# Epoch 49: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9906 - metric_choose_argument_global_y_train: 0.9485 - val_loss: -0.8602 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 50/100
# 487/505 [===========================>..] - ETA: 0s - loss: -0.9912 - metric_choose_argument_global_y_train: 0.9425
# Epoch 50: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9913 - metric_choose_argument_global_y_train: 0.9446 - val_loss: -0.8586 - val_metric_choose_argument_global_y_train: 0.3245
# Epoch 51/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9916 - metric_choose_argument_global_y_train: 0.9515
# Epoch 51: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9916 - metric_choose_argument_global_y_train: 0.9505 - val_loss: -0.8616 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 52/100
# 488/505 [===========================>..] - ETA: 0s - loss: -0.9911 - metric_choose_argument_global_y_train: 0.9529
# Epoch 52: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9911 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8586 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 53/100
# 492/505 [============================>.] - ETA: 0s - loss: -0.9919 - metric_choose_argument_global_y_train: 0.9553
# Epoch 53: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9919 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8594 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 54/100
# 488/505 [===========================>..] - ETA: 0s - loss: -0.9923 - metric_choose_argument_global_y_train: 0.9549
# Epoch 54: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9923 - metric_choose_argument_global_y_train: 0.9564 - val_loss: -0.8578 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 55/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9924 - metric_choose_argument_global_y_train: 0.9525
# Epoch 55: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9924 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8616 - val_metric_choose_argument_global_y_train: 0.3191
# Epoch 56/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9922 - metric_choose_argument_global_y_train: 0.9442
# Epoch 56: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9922 - metric_choose_argument_global_y_train: 0.9446 - val_loss: -0.8586 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 57/100
# 493/505 [============================>.] - ETA: 0s - loss: -0.9919 - metric_choose_argument_global_y_train: 0.9513
# Epoch 57: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9920 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8590 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 58/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9925 - metric_choose_argument_global_y_train: 0.9541
# Epoch 58: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9925 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8604 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 59/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9926 - metric_choose_argument_global_y_train: 0.9563
# Epoch 59: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9926 - metric_choose_argument_global_y_train: 0.9564 - val_loss: -0.8595 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 60/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9931 - metric_choose_argument_global_y_train: 0.9636
# Epoch 60: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9931 - metric_choose_argument_global_y_train: 0.9644 - val_loss: -0.8593 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 61/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9927 - metric_choose_argument_global_y_train: 0.9516
# Epoch 61: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9928 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8608 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 62/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9932 - metric_choose_argument_global_y_train: 0.9622
# Epoch 62: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9932 - metric_choose_argument_global_y_train: 0.9624 - val_loss: -0.8592 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 63/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9932 - metric_choose_argument_global_y_train: 0.9540
# Epoch 63: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9932 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8607 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 64/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9936 - metric_choose_argument_global_y_train: 0.9561
# Epoch 64: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9936 - metric_choose_argument_global_y_train: 0.9564 - val_loss: -0.8590 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 65/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9938 - metric_choose_argument_global_y_train: 0.9663
# Epoch 65: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9938 - metric_choose_argument_global_y_train: 0.9663 - val_loss: -0.8596 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 66/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9940 - metric_choose_argument_global_y_train: 0.9600
# Epoch 66: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9940 - metric_choose_argument_global_y_train: 0.9604 - val_loss: -0.8596 - val_metric_choose_argument_global_y_train: 0.3191
# Epoch 67/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9939 - metric_choose_argument_global_y_train: 0.9561
# Epoch 67: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9939 - metric_choose_argument_global_y_train: 0.9564 - val_loss: -0.8587 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 68/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9942 - metric_choose_argument_global_y_train: 0.9602
# Epoch 68: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9943 - metric_choose_argument_global_y_train: 0.9604 - val_loss: -0.8597 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 69/100
# 492/505 [============================>.] - ETA: 0s - loss: -0.9941 - metric_choose_argument_global_y_train: 0.9614
# Epoch 69: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9941 - metric_choose_argument_global_y_train: 0.9604 - val_loss: -0.8588 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 70/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9943 - metric_choose_argument_global_y_train: 0.9577
# Epoch 70: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9943 - metric_choose_argument_global_y_train: 0.9584 - val_loss: -0.8603 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 71/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9946 - metric_choose_argument_global_y_train: 0.9621
# Epoch 71: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9946 - metric_choose_argument_global_y_train: 0.9624 - val_loss: -0.8587 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 72/100
# 489/505 [============================>.] - ETA: 0s - loss: -0.9945 - metric_choose_argument_global_y_train: 0.9775
# Epoch 72: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9941 - metric_choose_argument_global_y_train: 0.9703 - val_loss: -0.8602 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 73/100
# 488/505 [===========================>..] - ETA: 0s - loss: -0.9938 - metric_choose_argument_global_y_train: 0.9652
# Epoch 73: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9938 - metric_choose_argument_global_y_train: 0.9644 - val_loss: -0.8603 - val_metric_choose_argument_global_y_train: 0.3191
# Epoch 74/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9948 - metric_choose_argument_global_y_train: 0.9682
# Epoch 74: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9948 - metric_choose_argument_global_y_train: 0.9683 - val_loss: -0.8607 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 75/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9951 - metric_choose_argument_global_y_train: 0.9701
# Epoch 75: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9951 - metric_choose_argument_global_y_train: 0.9703 - val_loss: -0.8603 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 76/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9949 - metric_choose_argument_global_y_train: 0.9679
# Epoch 76: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9949 - metric_choose_argument_global_y_train: 0.9683 - val_loss: -0.8599 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 77/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9953 - metric_choose_argument_global_y_train: 0.9683
# Epoch 77: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9953 - metric_choose_argument_global_y_train: 0.9683 - val_loss: -0.8613 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 78/100
# 489/505 [============================>.] - ETA: 0s - loss: -0.9952 - metric_choose_argument_global_y_train: 0.9714
# Epoch 78: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9952 - metric_choose_argument_global_y_train: 0.9703 - val_loss: -0.8606 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 79/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9953 - metric_choose_argument_global_y_train: 0.9677
# Epoch 79: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9953 - metric_choose_argument_global_y_train: 0.9683 - val_loss: -0.8590 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 80/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9951 - metric_choose_argument_global_y_train: 0.9738
# Epoch 80: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9948 - metric_choose_argument_global_y_train: 0.9723 - val_loss: -0.8619 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 81/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9946 - metric_choose_argument_global_y_train: 0.9663
# Epoch 81: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9947 - metric_choose_argument_global_y_train: 0.9663 - val_loss: -0.8598 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 82/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9956 - metric_choose_argument_global_y_train: 0.9739
# Epoch 82: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9956 - metric_choose_argument_global_y_train: 0.9743 - val_loss: -0.8603 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 83/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9960 - metric_choose_argument_global_y_train: 0.9717
# Epoch 83: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9960 - metric_choose_argument_global_y_train: 0.9723 - val_loss: -0.8603 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 84/100
# 491/505 [============================>.] - ETA: 0s - loss: -0.9961 - metric_choose_argument_global_y_train: 0.9695
# Epoch 84: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9961 - metric_choose_argument_global_y_train: 0.9703 - val_loss: -0.8609 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 85/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9962 - metric_choose_argument_global_y_train: 0.9722
# Epoch 85: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9962 - metric_choose_argument_global_y_train: 0.9723 - val_loss: -0.8610 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 86/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9959 - metric_choose_argument_global_y_train: 0.9761
# Epoch 86: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9959 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8615 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 87/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9958 - metric_choose_argument_global_y_train: 0.9741
# Epoch 87: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9958 - metric_choose_argument_global_y_train: 0.9743 - val_loss: -0.8616 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 88/100
# 490/505 [============================>.] - ETA: 0s - loss: -0.9965 - metric_choose_argument_global_y_train: 0.9735
# Epoch 88: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9964 - metric_choose_argument_global_y_train: 0.9723 - val_loss: -0.8623 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 89/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9964 - metric_choose_argument_global_y_train: 0.9662
# Epoch 89: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9964 - metric_choose_argument_global_y_train: 0.9663 - val_loss: -0.8609 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 90/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9959 - metric_choose_argument_global_y_train: 0.9760
# Epoch 90: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9960 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8622 - val_metric_choose_argument_global_y_train: 0.3138
# Epoch 91/100
# 493/505 [============================>.] - ETA: 0s - loss: -0.9957 - metric_choose_argument_global_y_train: 0.9696
# Epoch 91: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9957 - metric_choose_argument_global_y_train: 0.9703 - val_loss: -0.8608 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 92/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9957 - metric_choose_argument_global_y_train: 0.9760
# Epoch 92: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9957 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8617 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 93/100
# 493/505 [============================>.] - ETA: 0s - loss: -0.9960 - metric_choose_argument_global_y_train: 0.9757
# Epoch 93: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 5ms/step - loss: -0.9960 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8624 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 94/100
# 488/505 [===========================>..] - ETA: 0s - loss: -0.9965 - metric_choose_argument_global_y_train: 0.9775
# Epoch 94: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9965 - metric_choose_argument_global_y_train: 0.9782 - val_loss: -0.8619 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 95/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9761
# Epoch 95: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8615 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 96/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9819
# Epoch 96: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9822 - val_loss: -0.8608 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 97/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9964 - metric_choose_argument_global_y_train: 0.9778
# Epoch 97: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9963 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8613 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 98/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9959 - metric_choose_argument_global_y_train: 0.9721
# Epoch 98: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9959 - metric_choose_argument_global_y_train: 0.9723 - val_loss: -0.8612 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 99/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9780
# Epoch 99: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 5ms/step - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9782 - val_loss: -0.8616 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 100/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9762
# Epoch 100: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 2s 4ms/step - loss: -0.9967 - metric_choose_argument_global_y_train: 0.9762 - val_loss: -0.8624 - val_metric_choose_argument_global_y_train: 0.3085

# %%
global_history_df_2_layer = pd.DataFrame(global_history_2_layer.history)

# %%
output_folder_path = 'current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/'
os.makedirs(output_folder_path, exist_ok=True)
global_history_df_2_layer.to_csv(f'{output_folder_path}global_training_log.csv')
global_autoencoder_model_2_layer.save(f'{output_folder_path}global_autoencoder_model.keras')

# %% [markdown]
# ## 3-layer model

# %% [markdown]
# ### 3-layer architecture

# %%
# Layers
input_layer = tf.keras.layers.Input(shape=(768, ), name="Input")
hidden_layer_1 = tf.keras.layers.Dense(units=768*4, activation="relu", name="Hidden1")(input_layer)
hidden_layer_2 = tf.keras.layers.Dense(units=768*2, activation="relu", name="Hidden2")(hidden_layer_1)
hidden_layer_3 = tf.keras.layers.Dense(units=768, activation="relu", name="Hidden3")(hidden_layer_2)
output_layer = tf.keras.layers.Dense(units=768, activation="linear", name="Output")(hidden_layer_3)

# %%
# Model
autoencoder_model_3_layer = tf.keras.Model(inputs=input_layer, outputs=output_layer)
autoencoder_model_3_layer.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 768)]             0
#
#  Hidden1 (Dense)             (None, 3072)              2362368
#
#  Hidden2 (Dense)             (None, 1536)              4720128
#
#  Hidden3 (Dense)             (None, 768)               1180416
#
#  Output (Dense)              (None, 768)               590592
#
# =================================================================
# Total params: 8853504 (33.77 MB)
# Trainable params: 8853504 (33.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Global Training

# %%
# Global Model
global_autoencoder_model_3_layer = autoencoder_model_3_layer
global_autoencoder_model_3_layer.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_global_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='global_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='global_training_log.csv', separator=',', append=True)
global_history_3_layer = global_autoencoder_model_3_layer.fit(
  x=x_train,
  y=y_train,
  batch_size=1,
  epochs=100,
  validation_data = (x_test, y_test),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.7720 - metric_choose_argument_global_y_train: 0.0000e+00
# Epoch 1: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 5s 7ms/step - loss: -0.7722 - metric_choose_argument_global_y_train: 0.0000e+00 - val_loss: -0.7879 - val_metric_choose_argument_global_y_train: 0.0000e+00
# Epoch 2/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.7916 - metric_choose_argument_global_y_train: 0.0000e+00
# Epoch 2: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.7916 - metric_choose_argument_global_y_train: 0.0000e+00 - val_loss: -0.7926 - val_metric_choose_argument_global_y_train: 0.0106
# Epoch 3/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.7944 - metric_choose_argument_global_y_train: 0.0040
# Epoch 3: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.7946 - metric_choose_argument_global_y_train: 0.0040 - val_loss: -0.7929 - val_metric_choose_argument_global_y_train: 0.0053
# Epoch 4/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.7982 - metric_choose_argument_global_y_train: 0.0120
# Epoch 4: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.7981 - metric_choose_argument_global_y_train: 0.0119 - val_loss: -0.7973 - val_metric_choose_argument_global_y_train: 0.0053
# Epoch 5/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.8028 - metric_choose_argument_global_y_train: 0.0099
# Epoch 5: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8028 - metric_choose_argument_global_y_train: 0.0099 - val_loss: -0.7992 - val_metric_choose_argument_global_y_train: 0.0213
# Epoch 6/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.8080 - metric_choose_argument_global_y_train: 0.0279
# Epoch 6: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.8081 - metric_choose_argument_global_y_train: 0.0277 - val_loss: -0.8041 - val_metric_choose_argument_global_y_train: 0.0266
# Epoch 7/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.8138 - metric_choose_argument_global_y_train: 0.0445
# Epoch 7: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8138 - metric_choose_argument_global_y_train: 0.0436 - val_loss: -0.8068 - val_metric_choose_argument_global_y_train: 0.0160
# Epoch 8/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.8205 - metric_choose_argument_global_y_train: 0.0766
# Epoch 8: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8205 - metric_choose_argument_global_y_train: 0.0752 - val_loss: -0.8078 - val_metric_choose_argument_global_y_train: 0.0213
# Epoch 9/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.8260 - metric_choose_argument_global_y_train: 0.1036
# Epoch 9: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8261 - metric_choose_argument_global_y_train: 0.1050 - val_loss: -0.8111 - val_metric_choose_argument_global_y_train: 0.0479
# Epoch 10/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.8325 - metric_choose_argument_global_y_train: 0.1308
# Epoch 10: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.8327 - metric_choose_argument_global_y_train: 0.1327 - val_loss: -0.8115 - val_metric_choose_argument_global_y_train: 0.0479
# Epoch 11/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.8395 - metric_choose_argument_global_y_train: 0.1769
# Epoch 11: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.8394 - metric_choose_argument_global_y_train: 0.1762 - val_loss: -0.8146 - val_metric_choose_argument_global_y_train: 0.0745
# Epoch 12/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.8470 - metric_choose_argument_global_y_train: 0.2345
# Epoch 12: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8471 - metric_choose_argument_global_y_train: 0.2356 - val_loss: -0.8212 - val_metric_choose_argument_global_y_train: 0.0691
# Epoch 13/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.8554 - metric_choose_argument_global_y_train: 0.2866
# Epoch 13: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.8554 - metric_choose_argument_global_y_train: 0.2891 - val_loss: -0.8215 - val_metric_choose_argument_global_y_train: 0.0851
# Epoch 14/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.8638 - metric_choose_argument_global_y_train: 0.3546
# Epoch 14: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8638 - metric_choose_argument_global_y_train: 0.3525 - val_loss: -0.8218 - val_metric_choose_argument_global_y_train: 0.1170
# Epoch 15/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.8717 - metric_choose_argument_global_y_train: 0.4008
# Epoch 15: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.8717 - metric_choose_argument_global_y_train: 0.4020 - val_loss: -0.8227 - val_metric_choose_argument_global_y_train: 0.1383
# Epoch 16/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.8800 - metric_choose_argument_global_y_train: 0.4839
# Epoch 16: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.8795 - metric_choose_argument_global_y_train: 0.4812 - val_loss: -0.8293 - val_metric_choose_argument_global_y_train: 0.1489
# Epoch 17/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.8877 - metric_choose_argument_global_y_train: 0.5190
# Epoch 17: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 8ms/step - loss: -0.8876 - metric_choose_argument_global_y_train: 0.5188 - val_loss: -0.8286 - val_metric_choose_argument_global_y_train: 0.1915
# Epoch 18/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.8958 - metric_choose_argument_global_y_train: 0.5788
# Epoch 18: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.8956 - metric_choose_argument_global_y_train: 0.5743 - val_loss: -0.8310 - val_metric_choose_argument_global_y_train: 0.2074
# Epoch 19/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9023 - metric_choose_argument_global_y_train: 0.6362
# Epoch 19: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9023 - metric_choose_argument_global_y_train: 0.6356 - val_loss: -0.8287 - val_metric_choose_argument_global_y_train: 0.2074
# Epoch 20/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9085 - metric_choose_argument_global_y_train: 0.6694
# Epoch 20: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9082 - metric_choose_argument_global_y_train: 0.6693 - val_loss: -0.8290 - val_metric_choose_argument_global_y_train: 0.2181
# Epoch 21/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9142 - metric_choose_argument_global_y_train: 0.6834
# Epoch 21: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9142 - metric_choose_argument_global_y_train: 0.6871 - val_loss: -0.8323 - val_metric_choose_argument_global_y_train: 0.2553
# Epoch 22/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9209 - metric_choose_argument_global_y_train: 0.7500
# Epoch 22: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9209 - metric_choose_argument_global_y_train: 0.7505 - val_loss: -0.8336 - val_metric_choose_argument_global_y_train: 0.2447
# Epoch 23/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9264 - metric_choose_argument_global_y_train: 0.7626
# Epoch 23: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9264 - metric_choose_argument_global_y_train: 0.7624 - val_loss: -0.8350 - val_metric_choose_argument_global_y_train: 0.2606
# Epoch 24/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9302 - metric_choose_argument_global_y_train: 0.7877
# Epoch 24: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9302 - metric_choose_argument_global_y_train: 0.7861 - val_loss: -0.8355 - val_metric_choose_argument_global_y_train: 0.2713
# Epoch 25/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9349 - metric_choose_argument_global_y_train: 0.8052
# Epoch 25: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9347 - metric_choose_argument_global_y_train: 0.8040 - val_loss: -0.8369 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 26/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9386 - metric_choose_argument_global_y_train: 0.8370
# Epoch 26: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9388 - metric_choose_argument_global_y_train: 0.8376 - val_loss: -0.8375 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 27/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9416 - metric_choose_argument_global_y_train: 0.8253
# Epoch 27: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9418 - metric_choose_argument_global_y_train: 0.8277 - val_loss: -0.8394 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 28/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9449 - metric_choose_argument_global_y_train: 0.8506
# Epoch 28: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9449 - metric_choose_argument_global_y_train: 0.8475 - val_loss: -0.8391 - val_metric_choose_argument_global_y_train: 0.2819
# Epoch 29/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9481 - metric_choose_argument_global_y_train: 0.8460
# Epoch 29: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9482 - metric_choose_argument_global_y_train: 0.8475 - val_loss: -0.8385 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 30/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9507 - metric_choose_argument_global_y_train: 0.8477
# Epoch 30: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9507 - metric_choose_argument_global_y_train: 0.8475 - val_loss: -0.8401 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 31/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9531 - metric_choose_argument_global_y_train: 0.8712
# Epoch 31: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9530 - metric_choose_argument_global_y_train: 0.8673 - val_loss: -0.8413 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 32/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9552 - metric_choose_argument_global_y_train: 0.8535
# Epoch 32: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9552 - metric_choose_argument_global_y_train: 0.8535 - val_loss: -0.8405 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 33/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9561 - metric_choose_argument_global_y_train: 0.8635
# Epoch 33: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9564 - metric_choose_argument_global_y_train: 0.8653 - val_loss: -0.8426 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 34/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9585 - metric_choose_argument_global_y_train: 0.8612
# Epoch 34: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9585 - metric_choose_argument_global_y_train: 0.8634 - val_loss: -0.8430 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 35/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9604 - metric_choose_argument_global_y_train: 0.8785
# Epoch 35: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9606 - metric_choose_argument_global_y_train: 0.8792 - val_loss: -0.8436 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 36/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9622 - metric_choose_argument_global_y_train: 0.8683
# Epoch 36: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9621 - metric_choose_argument_global_y_train: 0.8693 - val_loss: -0.8406 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 37/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9633 - metric_choose_argument_global_y_train: 0.8732
# Epoch 37: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9635 - metric_choose_argument_global_y_train: 0.8752 - val_loss: -0.8422 - val_metric_choose_argument_global_y_train: 0.2819
# Epoch 38/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9646 - metric_choose_argument_global_y_train: 0.8628
# Epoch 38: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9645 - metric_choose_argument_global_y_train: 0.8634 - val_loss: -0.8408 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 39/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9659 - metric_choose_argument_global_y_train: 0.8708
# Epoch 39: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9659 - metric_choose_argument_global_y_train: 0.8713 - val_loss: -0.8426 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 40/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9669 - metric_choose_argument_global_y_train: 0.8782
# Epoch 40: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9670 - metric_choose_argument_global_y_train: 0.8792 - val_loss: -0.8425 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 41/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9680 - metric_choose_argument_global_y_train: 0.8810
# Epoch 41: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9679 - metric_choose_argument_global_y_train: 0.8792 - val_loss: -0.8430 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 42/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9692 - metric_choose_argument_global_y_train: 0.8876
# Epoch 42: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9690 - metric_choose_argument_global_y_train: 0.8871 - val_loss: -0.8445 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 43/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9697 - metric_choose_argument_global_y_train: 0.8871
# Epoch 43: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9697 - metric_choose_argument_global_y_train: 0.8871 - val_loss: -0.8449 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 44/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9708 - metric_choose_argument_global_y_train: 0.8922
# Epoch 44: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9709 - metric_choose_argument_global_y_train: 0.8931 - val_loss: -0.8449 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 45/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9721 - metric_choose_argument_global_y_train: 0.8878
# Epoch 45: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9720 - metric_choose_argument_global_y_train: 0.8891 - val_loss: -0.8439 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 46/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9726 - metric_choose_argument_global_y_train: 0.8911
# Epoch 46: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9726 - metric_choose_argument_global_y_train: 0.8911 - val_loss: -0.8457 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 47/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9730 - metric_choose_argument_global_y_train: 0.9069
# Epoch 47: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9727 - metric_choose_argument_global_y_train: 0.9050 - val_loss: -0.8424 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 48/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9734 - metric_choose_argument_global_y_train: 0.8862
# Epoch 48: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9734 - metric_choose_argument_global_y_train: 0.8871 - val_loss: -0.8450 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 49/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9742 - metric_choose_argument_global_y_train: 0.9006
# Epoch 49: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9742 - metric_choose_argument_global_y_train: 0.8990 - val_loss: -0.8454 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 50/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9754 - metric_choose_argument_global_y_train: 0.9044
# Epoch 50: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9752 - metric_choose_argument_global_y_train: 0.9030 - val_loss: -0.8462 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 51/100
# 495/505 [============================>.] - ETA: 0s - loss: -0.9758 - metric_choose_argument_global_y_train: 0.9091
# Epoch 51: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9759 - metric_choose_argument_global_y_train: 0.9089 - val_loss: -0.8456 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 52/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9761 - metric_choose_argument_global_y_train: 0.9020
# Epoch 52: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9761 - metric_choose_argument_global_y_train: 0.9030 - val_loss: -0.8460 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 53/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9767 - metric_choose_argument_global_y_train: 0.9022
# Epoch 53: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9766 - metric_choose_argument_global_y_train: 0.8990 - val_loss: -0.8458 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 54/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9770 - metric_choose_argument_global_y_train: 0.8934
# Epoch 54: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9768 - metric_choose_argument_global_y_train: 0.8931 - val_loss: -0.8461 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 55/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9773 - metric_choose_argument_global_y_train: 0.8984
# Epoch 55: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9774 - metric_choose_argument_global_y_train: 0.8990 - val_loss: -0.8449 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 56/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9782 - metric_choose_argument_global_y_train: 0.8931
# Epoch 56: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9782 - metric_choose_argument_global_y_train: 0.8931 - val_loss: -0.8449 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 57/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9788 - metric_choose_argument_global_y_train: 0.9109
# Epoch 57: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9788 - metric_choose_argument_global_y_train: 0.9109 - val_loss: -0.8481 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 58/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9795 - metric_choose_argument_global_y_train: 0.9246
# Epoch 58: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9795 - metric_choose_argument_global_y_train: 0.9248 - val_loss: -0.8455 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 59/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9800 - metric_choose_argument_global_y_train: 0.9116
# Epoch 59: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9799 - metric_choose_argument_global_y_train: 0.9109 - val_loss: -0.8461 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 60/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9797 - metric_choose_argument_global_y_train: 0.9089
# Epoch 60: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9796 - metric_choose_argument_global_y_train: 0.9089 - val_loss: -0.8460 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 61/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9801 - metric_choose_argument_global_y_train: 0.9030
# Epoch 61: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9801 - metric_choose_argument_global_y_train: 0.9030 - val_loss: -0.8459 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 62/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9805 - metric_choose_argument_global_y_train: 0.9177
# Epoch 62: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9806 - metric_choose_argument_global_y_train: 0.9168 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 63/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9809 - metric_choose_argument_global_y_train: 0.9062
# Epoch 63: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9810 - metric_choose_argument_global_y_train: 0.9069 - val_loss: -0.8474 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 64/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9813 - metric_choose_argument_global_y_train: 0.9237
# Epoch 64: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9813 - metric_choose_argument_global_y_train: 0.9228 - val_loss: -0.8470 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 65/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9821 - metric_choose_argument_global_y_train: 0.9336
# Epoch 65: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9821 - metric_choose_argument_global_y_train: 0.9347 - val_loss: -0.8474 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 66/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9822 - metric_choose_argument_global_y_train: 0.9217
# Epoch 66: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9823 - metric_choose_argument_global_y_train: 0.9228 - val_loss: -0.8480 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 67/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9823 - metric_choose_argument_global_y_train: 0.9242
# Epoch 67: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9823 - metric_choose_argument_global_y_train: 0.9248 - val_loss: -0.8484 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 68/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9822 - metric_choose_argument_global_y_train: 0.9242
# Epoch 68: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9824 - metric_choose_argument_global_y_train: 0.9248 - val_loss: -0.8481 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 69/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9826 - metric_choose_argument_global_y_train: 0.9355
# Epoch 69: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9827 - metric_choose_argument_global_y_train: 0.9347 - val_loss: -0.8475 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 70/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9830 - metric_choose_argument_global_y_train: 0.9457
# Epoch 70: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9831 - metric_choose_argument_global_y_train: 0.9426 - val_loss: -0.8486 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 71/100
# 497/505 [============================>.] - ETA: 0s - loss: -0.9838 - metric_choose_argument_global_y_train: 0.9457
# Epoch 71: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9839 - metric_choose_argument_global_y_train: 0.9465 - val_loss: -0.8482 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 72/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9841 - metric_choose_argument_global_y_train: 0.9386
# Epoch 72: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9841 - metric_choose_argument_global_y_train: 0.9386 - val_loss: -0.8481 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 73/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9842 - metric_choose_argument_global_y_train: 0.9406
# Epoch 73: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9842 - metric_choose_argument_global_y_train: 0.9406 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 74/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9842 - metric_choose_argument_global_y_train: 0.9315
# Epoch 74: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9842 - metric_choose_argument_global_y_train: 0.9327 - val_loss: -0.8481 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 75/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9842 - metric_choose_argument_global_y_train: 0.9418
# Epoch 75: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9842 - metric_choose_argument_global_y_train: 0.9426 - val_loss: -0.8471 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 76/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9845 - metric_choose_argument_global_y_train: 0.9420
# Epoch 76: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9844 - metric_choose_argument_global_y_train: 0.9406 - val_loss: -0.8481 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 77/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9844 - metric_choose_argument_global_y_train: 0.9359
# Epoch 77: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9844 - metric_choose_argument_global_y_train: 0.9366 - val_loss: -0.8473 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 78/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9849 - metric_choose_argument_global_y_train: 0.9324
# Epoch 78: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9849 - metric_choose_argument_global_y_train: 0.9327 - val_loss: -0.8486 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 79/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9857 - metric_choose_argument_global_y_train: 0.9456
# Epoch 79: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9857 - metric_choose_argument_global_y_train: 0.9465 - val_loss: -0.8492 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 80/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9858 - metric_choose_argument_global_y_train: 0.9405
# Epoch 80: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9857 - metric_choose_argument_global_y_train: 0.9406 - val_loss: -0.8494 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 81/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9857 - metric_choose_argument_global_y_train: 0.9422
# Epoch 81: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9857 - metric_choose_argument_global_y_train: 0.9426 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 82/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9861 - metric_choose_argument_global_y_train: 0.9460
# Epoch 82: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9860 - metric_choose_argument_global_y_train: 0.9446 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 83/100
# 496/505 [============================>.] - ETA: 0s - loss: -0.9862 - metric_choose_argument_global_y_train: 0.9516
# Epoch 83: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9861 - metric_choose_argument_global_y_train: 0.9485 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 84/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9858 - metric_choose_argument_global_y_train: 0.9423
# Epoch 84: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9858 - metric_choose_argument_global_y_train: 0.9426 - val_loss: -0.8495 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 85/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9862 - metric_choose_argument_global_y_train: 0.9379
# Epoch 85: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9861 - metric_choose_argument_global_y_train: 0.9386 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 86/100
# 494/505 [============================>.] - ETA: 0s - loss: -0.9866 - metric_choose_argument_global_y_train: 0.9534
# Epoch 86: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9866 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8491 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 87/100
# 503/505 [============================>.] - ETA: 0s - loss: -0.9866 - metric_choose_argument_global_y_train: 0.9463
# Epoch 87: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9866 - metric_choose_argument_global_y_train: 0.9465 - val_loss: -0.8486 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 88/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9867 - metric_choose_argument_global_y_train: 0.9505
# Epoch 88: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9867 - metric_choose_argument_global_y_train: 0.9505 - val_loss: -0.8499 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 89/100
# 499/505 [============================>.] - ETA: 0s - loss: -0.9873 - metric_choose_argument_global_y_train: 0.9539
# Epoch 89: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9872 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8494 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 90/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9874 - metric_choose_argument_global_y_train: 0.9425
# Epoch 90: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9874 - metric_choose_argument_global_y_train: 0.9426 - val_loss: -0.8498 - val_metric_choose_argument_global_y_train: 0.2872
# Epoch 91/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9876 - metric_choose_argument_global_y_train: 0.9545
# Epoch 91: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9876 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8498 - val_metric_choose_argument_global_y_train: 0.2926
# Epoch 92/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9875 - metric_choose_argument_global_y_train: 0.9544
# Epoch 92: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9875 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8484 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 93/100
# 498/505 [============================>.] - ETA: 0s - loss: -0.9877 - metric_choose_argument_global_y_train: 0.9478
# Epoch 93: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9877 - metric_choose_argument_global_y_train: 0.9485 - val_loss: -0.8493 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 94/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9880 - metric_choose_argument_global_y_train: 0.9542
# Epoch 94: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9880 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8504 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 95/100
# 501/505 [============================>.] - ETA: 0s - loss: -0.9883 - metric_choose_argument_global_y_train: 0.9501
# Epoch 95: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9882 - metric_choose_argument_global_y_train: 0.9505 - val_loss: -0.8493 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 96/100
# 504/505 [============================>.] - ETA: 0s - loss: -0.9875 - metric_choose_argument_global_y_train: 0.9504
# Epoch 96: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9875 - metric_choose_argument_global_y_train: 0.9505 - val_loss: -0.8483 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 97/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9873 - metric_choose_argument_global_y_train: 0.9465
# Epoch 97: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 6ms/step - loss: -0.9873 - metric_choose_argument_global_y_train: 0.9465 - val_loss: -0.8487 - val_metric_choose_argument_global_y_train: 0.3032
# Epoch 98/100
# 502/505 [============================>.] - ETA: 0s - loss: -0.9877 - metric_choose_argument_global_y_train: 0.9602
# Epoch 98: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 4s 7ms/step - loss: -0.9875 - metric_choose_argument_global_y_train: 0.9564 - val_loss: -0.8481 - val_metric_choose_argument_global_y_train: 0.3085
# Epoch 99/100
# 500/505 [============================>.] - ETA: 0s - loss: -0.9888 - metric_choose_argument_global_y_train: 0.9440
# Epoch 99: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9887 - metric_choose_argument_global_y_train: 0.9446 - val_loss: -0.8480 - val_metric_choose_argument_global_y_train: 0.2979
# Epoch 100/100
# 505/505 [==============================] - ETA: 0s - loss: -0.9893 - metric_choose_argument_global_y_train: 0.9584
# Epoch 100: saving model to global_autoencoder_weights.keras
# 505/505 [==============================] - 3s 7ms/step - loss: -0.9893 - metric_choose_argument_global_y_train: 0.9584 - val_loss: -0.8493 - val_metric_choose_argument_global_y_train: 0.3085

# %%
global_history_df_3_layer = pd.DataFrame(global_history_3_layer.history)

# %%
output_folder_path = 'current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/'
os.makedirs(output_folder_path, exist_ok=True)
global_history_df_3_layer.to_csv(f'{output_folder_path}global_training_log.csv')
global_autoencoder_model_3_layer.save(f'{output_folder_path}global_autoencoder_model.keras')

# %% [markdown]
# ## Plot training history

# %% [markdown]
# ### 1-layer architecture training history

# %%
# Access training history
combined_history_1_layer = pd.DataFrame(pd.read_csv('current-data-dump/nomic-autoencoder/combined_training_log.csv'))
combined_history_1_layer = pd.melt(combined_history_1_layer, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_combined_y_train', 'val_metric_choose_argument_combined_y_train'], var_name='dataset', value_name='accuracy')
combined_history_1_layer = combined_history_1_layer.replace(['metric_choose_argument_combined_y_train', 'val_metric_choose_argument_combined_y_train'], ['training set', 'validation set'])
combined_history_1_layer.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
combined_history_1_layer['layers'] = '1'

# %% [markdown]
# ### 2-layer architecture training history

# %%
# Access training history
global_history_2_layer = pd.DataFrame(pd.read_csv('current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/global_training_log.csv'))
global_history_2_layer = pd.melt(global_history_2_layer, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], var_name='dataset', value_name='accuracy')
global_history_2_layer = global_history_2_layer.replace(['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], ['training set', 'validation set'])
global_history_2_layer.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
global_history_2_layer['layers'] = '2'

# %%
global_training_plot_2_layer = ggplot(global_history_2_layer, aes(x='epoch', y='accuracy', linetype='dataset')) + geom_line() + labs(title='Learning Curve of Model Trained on Unshuffled Data', x='Epoch', y='Accuracy')
ggsave(global_training_plot_2_layer, "current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/global_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/global_training_plot.png

# %% [markdown]
# ### 3-layer architecture training history

# %%
# Access training history
global_history_3_layer = pd.DataFrame(pd.read_csv("current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/global_training_log.csv"))
global_history_3_layer = pd.melt(global_history_3_layer, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], var_name='dataset', value_name='accuracy')
global_history_3_layer = global_history_3_layer.replace(['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], ['training set', 'validation set'])
global_history_3_layer.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
global_history_3_layer['layers'] = '3'

# %%
global_training_plot_3_layer = ggplot(global_history_3_layer, aes(x='epoch', y='accuracy', linetype='dataset')) + geom_line() + labs(title='Learning Curve of Model Trained on Shuffled Data', x='Epoch', y='Accuracy')
ggsave(global_training_plot_3_layer, "current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/global_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/global_training_plot.png

# %% [markdown]
# ## Combined Training Plots

# %%
combined_global_training_df = pd.concat([combined_history_1_layer, global_history_2_layer, global_history_3_layer])

# %%
color_map = {'1': '#AAAAAA', '2': '#777777', '3': 'black'}
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

combined_global_plot = (
  ggplot(combined_global_training_df, aes(x='epoch', y='accuracy', linetype='dataset', color='layers')) +
  geom_line(size=2) +
  labs(title='Learning Curves of 1-Layer vs 2-Layer vs 3-Layer Networks (SciFact; Nomic)', x='Epoch', y='Accuracy') +
  scale_color_manual(color_map) +
  scale_linetype_manual(linetype_map) +
  theme(
    figure_size=(16,24),
    axis_title=element_text(size=32),
    axis_text=element_text(size=24),
    legend_title=element_text(size=32, lineheight=1.5),
    legend_text=element_text(size=24, lineheight=1.5),
    plot_title=element_text(size=40, wrap=True, lineheight=1.5),
    legend_position="bottom",
    legend_key_width=64
  ) +
  guides(fill = guide_legend(byrow = True))
)
ggsave(combined_global_plot, "current-data-dump/nomic-autoencoder/other-architectures/combined_global_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/nomic-autoencoder/other-architectures/combined_global_training_plot.png

# %%
combined_global_plot
# Out:
# <Figure Size: (1600 x 2400)>

# %% [markdown]
# ## Final Export

# %%
other_architectures_file_path = 'current-data-dump/nomic-autoencoder/other-architectures/'
other_architectures_file_path_zip = 'current-data-dump/nomic-autoencoder/other-architectures/'
shutil.make_archive(other_architectures_file_path_zip, 'zip', other_architectures_file_path)
print(f"Zip file created at: {other_architectures_file_path_zip}")
result = subprocess.run([f"osf -p sakjg upload --force {other_architectures_file_path_zip}.zip data-dump/nomic-autoencoder/other_architectures.zip"], shell=True, capture_output=True, text=True)
print(result.stderr)
print(f"File: {other_architectures_file_path_zip} uploaded at osfstorage")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.10/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1775             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1776                 shutil.copyfileobj(src, dest, 1024*8)
#    1777
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
#     197             break
# --> 198         fdst_write(buf)
#     199
#
# /usr/lib/python3.10/zipfile.py in write(self, data)
#    1138         if self._compressor:
# -> 1139             data = self._compressor.compress(data)
#    1140             self._compress_size += len(data)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-cb78add21ac7> in <cell line: 3>()
#       1 other_architectures_file_path = 'current-data-dump/ada-autoencoder/other-architectures/'
#       2 other_architectures_file_path_zip = 'current-data-dump/ada-autoencoder/other-architectures/'
# ----> 3 shutil.make_archive(other_architectures_file_path_zip, 'zip', other_architectures_file_path)
#       4 print(f"Zip file created at: {other_architectures_file_path_zip}")
#       5 result = subprocess.run([f"osf -p sakjg upload --force {other_architectures_file_path_zip}.zip data-dump/ada002-autoencoder/other_architectures.zip"], shell=True, capture_output=True, text=True)
#
# /usr/lib/python3.10/shutil.py in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1122
#    1123     try:
# -> 1124         filename = func(base_name, base_dir, **kwargs)
#    1125     finally:
#    1126         if save_cwd is not None:
#
# /usr/lib/python3.10/shutil.py in _make_zipfile(base_name, base_dir, verbose, dry_run, logger, owner, group, root_dir)
#    1007                     if os.path.isfile(path):
#    1008                         arcname = os.path.join(arcdirpath, name)
# -> 1009                         zf.write(path, arcname)
#    1010                         if logger is not None:
#    1011                             logger.info("adding '%s'", path)
#
# /usr/lib/python3.10/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1773                 self.start_dir = self.fp.tell()
#    1774         else:
# -> 1775             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
#    1776                 shutil.copyfileobj(src, dest, 1024*8)
#    1777
#
# /usr/lib/python3.10/zipfile.py in close(self)
#    1168                 if not self._zip64:
#    1169                     if self._file_size > ZIP64_LIMIT:
# -> 1170                         raise RuntimeError(
#    1171                             'File size unexpectedly exceeded ZIP64 limit')
#    1172                     if self._compress_size > ZIP64_LIMIT:
#
# RuntimeError: File size unexpectedly exceeded ZIP64 limit

# %% [markdown]
# ## Import data

# %%
subprocess.run("osf -p sakjg fetch --force osfstorage/data-dump/nomic-autoencoder/other_architectures.zip", shell=True)
print("other_architectures.zip successfully imported")
nomic_autoencoder_file_path_zip = 'other_architectures.zip'
nomic_autoencoder_file_path = 'current-data-dump/nomic-autoencoder/other-architectures'
os.makedirs(nomic_autoencoder_file_path, exist_ok=True)
with zipfile.ZipFile(nomic_autoencoder_file_path_zip, 'r') as zip_ref:
  zip_ref.extractall(nomic_autoencoder_file_path)
extracted_files = os.listdir(nomic_autoencoder_file_path)
print("Files extracted:", extracted_files)
# Out:
# other_architectures.zip successfully imported
# Files extracted: ['3-layer-architecture', 'combined_global_training_plot.png', '.zip', '2-layer-architecture']
