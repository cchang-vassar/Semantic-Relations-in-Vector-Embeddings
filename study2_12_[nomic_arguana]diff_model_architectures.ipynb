# %% [markdown]
# <a href="https://colab.research.google.com/github/cchang-vassar/Semantic-Relations-in-Vector-Embeddings/blob/main/study2_12_%5Bnomic_arguana%5Ddiff_model_architectures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [nomic-arguana] Autoencoder: Generate Corresponding Embedding

# %% [markdown]
# Try 2 new architectures:
#
#
# 1.   2 hidden layers: 1536*2 -> 1536
# 2.   3 hidden layers: 1536\*4 -> 1536\*2 -> 1536

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Imports

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import os
import subprocess
import zipfile
import shutil
import pickle
import tensorflow as tf
import pandas as pd
import numpy as np
from google.colab import userdata
from scipy import spatial
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from plotnine import ggplot, geom_line, aes, ggsave, labs, theme, element_text, guides, guide_legend, scale_color_manual, scale_linetype_manual

# %% [markdown]
# ### OSF Setup

# %%
# !pip install osfclient
# Out:
# Collecting osfclient
#   Downloading osfclient-0.0.5-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from osfclient) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from osfclient) (4.66.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from osfclient) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->osfclient) (2024.2.2)
# Installing collected packages: osfclient
# Successfully installed osfclient-0.0.5

# %%
import osfclient.cli

# %%
from osfclient.api import OSF
from osfclient.models import Project, Storage
from io import BytesIO

# %%
os.environ["OSF_USERNAME"] = userdata.get("OSF_USERNAME")
OSF_USERNAME = os.environ["OSF_USERNAME"]

# %%
os.environ["OSF_PASSWORD"] = userdata.get("OSF_PASSWORD")
OSF_PASSWORD = os.environ["OSF_PASSWORD"]

# %%
os.environ["OSF_TOKEN"] = userdata.get("OSF_TOKEN")
OSF_TOKEN = os.environ["OSF_TOKEN"]

# %%
os.environ["OSF_PROJECT_ID"] = userdata.get("OSF_PROJECT_ID")
OSF_PROJECT_ID = os.environ["OSF_PROJECT_ID"]

# %% [markdown]
# ## Data

# %% [markdown]
# ### Import training data from OSF

# %%
# !osf -p sakjg fetch osfstorage/data-dump/nomic-autoencoder/nomic_autoencoder.zip
# Out:
# 100% 255M/255M [00:04<00:00, 62.4Mbytes/s]

# %%
# !osf -p sakjg fetch osfstorage/data-dump/nomic-autoencoder/nomic_embeddings_dump.zip
# Out:
# 100% 116M/116M [00:02<00:00, 54.1Mbytes/s]

# %%
nomic_autoencoder_file_path = 'nomic_autoencoder.zip'
output_folder_path = 'current-data-dump/nomic-autoencoder'
os.makedirs(output_folder_path, exist_ok=True)

with zipfile.ZipFile(nomic_autoencoder_file_path, 'r') as zip_ref:
  zip_ref.extractall(output_folder_path)

extracted_files = os.listdir(output_folder_path)
print("Files extracted:", extracted_files)
# Out:
# Files extracted: ['nomic_shuffled_sd_autoencoder_weights.keras', 'nomic_cla_autoencoder_weights.keras', 'nomic_clu_autoencoder_model.keras', 'x_test_cla.pkl', 'nomic_sd_training_plot.png', 'nomic_shuffled_sq_training_log.csv', 'y_test_sd.pkl', 'nomic_cla_training_log.csv', 'nomic_shuffled_cla_autoencoder_model.keras', 'x_train_cla.pkl', 'y_test_cla.pkl', 'nomic_shuffled_sq_autoencoder_model.keras', 'y_train_sq.pkl', 'x_test_sq.pkl', 'nomic_shuffled_clu_autoencoder_model.keras', 'nomic_shuffled_cla_training_log.csv', 'x_train_clu.pkl', 'nomic_clu_training_plot.png', 'nomic_sd_autoencoder_weights.keras', 'y_train_clu.pkl', 'nomic_cla_training_plot.png', 'y_train_cla.pkl', 'x_test_sd.pkl', 'nomic_clu_autoencoder_weights.keras', 'nomic_shuffled_sd_autoencoder_model.keras', 'nomic_shuffled_sd_training_log.csv', 'y_test_sq.pkl', 'nomic_sd_training_log.csv', 'nomic_sq_training_log.csv', 'nomic_shuffled_clu_autoencoder_weights.keras', 'nomic_shuffled_cla_autoencoder_weights.keras', 'nomic_shuffled_sq_autoencoder_weights.keras', 'nomic_combined_training_plot.png', 'x_train_sd.pkl', 'nomic_sq_training_plot.png', 'x_train_sq.pkl', 'nomic_sq_autoencoder_weights.keras', 'nomic_shuffled_clu_training_log.csv', 'nomic_sq_autoencoder_model.keras', 'y_test_clu.pkl', 'y_train_sd.pkl', 'nomic_cla_autoencoder_model.keras', '.ipynb_checkpoints', 'nomic_clu_training_log.csv', 'nomic_sd_autoencoder_model.keras', 'nomic_shuffled_combined_training_plot.png', 'x_test_clu.pkl']

# %%
nomic_embeddings_file_path = 'nomic_embeddings_dump.zip'
output_folder_path = 'current-data-dump/embeddings-dump'
os.makedirs(output_folder_path, exist_ok=True)

with zipfile.ZipFile(nomic_embeddings_file_path, 'r') as zip_ref:
  zip_ref.extractall(output_folder_path)

extracted_files = os.listdir(output_folder_path)
print("Files extracted:", extracted_files)
# Out:
# Files extracted: ['training_sd_embeddings.pkl', 'test_sq_embeddings.pkl', 'training_clu_embeddings.pkl', 'training_cla_embeddings.pkl', 'test_sd_embeddings.pkl', 'test_clu_embeddings.pkl', 'test_cla_embeddings.pkl', '.ipynb_checkpoints', 'training_sq_embeddings.pkl']

# %%
x_train = pd.read_pickle('current-data-dump/nomic-autoencoder/x_train_sd.pkl')
y_train = pd.read_pickle('current-data-dump/nomic-autoencoder/y_train_sd.pkl')
x_test = pd.read_pickle('current-data-dump/nomic-autoencoder/x_test_sd.pkl')
y_test = pd.read_pickle('current-data-dump/nomic-autoencoder/y_test_sd.pkl')

# %% [markdown]
# ## Metric

# %%
@tf.keras.saving.register_keras_serializable()
def metric_choose_argument_global_y_train(y_true, y_pred):
  """global_metric"""
  global_training_df_32 = tf.cast(pd.concat([x_train, y_train, x_test, y_test]), dtype=tf.float32)

  cos_sim_pred = tf.matmul(global_training_df_32, y_pred, transpose_b=True) / tf.reshape(tf.norm(y_pred) * tf.norm(global_training_df_32, axis=1), [-1, 1])
  cos_sim_true = tf.matmul(global_training_df_32, y_true, transpose_b=True) / tf.reshape(tf.norm(y_true) * tf.norm(global_training_df_32, axis=1), [-1, 1])

  max_cos_sim_pred = tf.math.argmax(cos_sim_pred)
  max_cos_sim_true = tf.math.argmax(cos_sim_true)

  return tf.math.count_nonzero(tf.equal(max_cos_sim_pred, max_cos_sim_true))

# %% [markdown]
# ## 2-layer model

# %% [markdown]
# ### 2-layer architecture

# %%
# Layers
input_layer = tf.keras.layers.Input(shape=(768, ), name="Input")
hidden_layer_1 = tf.keras.layers.Dense(units=768*2, activation="relu", name="Hidden1")(input_layer)
hidden_layer_2 = tf.keras.layers.Dense(units=768, activation="relu", name="Hidden2")(hidden_layer_1)
output_layer = tf.keras.layers.Dense(units=768, activation="linear", name="Output")(hidden_layer_2)

# %%
# Model
autoencoder_model_2_layer = tf.keras.Model(inputs=input_layer, outputs=output_layer)
autoencoder_model_2_layer.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 768)]             0
#
#  Hidden1 (Dense)             (None, 1536)              1181184
#
#  Hidden2 (Dense)             (None, 768)               1180416
#
#  Output (Dense)              (None, 768)               590592
#
# =================================================================
# Total params: 2952192 (11.26 MB)
# Trainable params: 2952192 (11.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Global Training

# %%
# Global Model
global_autoencoder_model_2_layer = autoencoder_model_2_layer
global_autoencoder_model_2_layer.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_global_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='global_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='global_training_log.csv', separator=',', append=True)
global_history_2_layer = global_autoencoder_model_2_layer.fit(
  x=x_train,
  y=y_train,
  batch_size=1,
  epochs=50,
  validation_data = (x_test, y_test),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/50
# 4065/4065 [==============================] - ETA: 0s - loss: -0.8197 - metric_choose_argument_global_y_train: 0.0167
# Epoch 1: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 24s 5ms/step - loss: -0.8197 - metric_choose_argument_global_y_train: 0.0167 - val_loss: -0.8356 - val_metric_choose_argument_global_y_train: 0.0300
# Epoch 2/50
# 4055/4065 [============================>.] - ETA: 0s - loss: -0.8524 - metric_choose_argument_global_y_train: 0.0612
# Epoch 2: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.8524 - metric_choose_argument_global_y_train: 0.0610 - val_loss: -0.8470 - val_metric_choose_argument_global_y_train: 0.0493
# Epoch 3/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.8667 - metric_choose_argument_global_y_train: 0.1184
# Epoch 3: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.8667 - metric_choose_argument_global_y_train: 0.1183 - val_loss: -0.8535 - val_metric_choose_argument_global_y_train: 0.0792
# Epoch 4/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.8775 - metric_choose_argument_global_y_train: 0.1745
# Epoch 4: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.8774 - metric_choose_argument_global_y_train: 0.1747 - val_loss: -0.8569 - val_metric_choose_argument_global_y_train: 0.1064
# Epoch 5/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.8865 - metric_choose_argument_global_y_train: 0.2713
# Epoch 5: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.8865 - metric_choose_argument_global_y_train: 0.2708 - val_loss: -0.8605 - val_metric_choose_argument_global_y_train: 0.1335
# Epoch 6/50
# 4056/4065 [============================>.] - ETA: 0s - loss: -0.8941 - metric_choose_argument_global_y_train: 0.3602
# Epoch 6: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.8941 - metric_choose_argument_global_y_train: 0.3597 - val_loss: -0.8621 - val_metric_choose_argument_global_y_train: 0.1806
# Epoch 7/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9010 - metric_choose_argument_global_y_train: 0.4501
# Epoch 7: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9010 - metric_choose_argument_global_y_train: 0.4494 - val_loss: -0.8645 - val_metric_choose_argument_global_y_train: 0.2106
# Epoch 8/50
# 4050/4065 [============================>.] - ETA: 0s - loss: -0.9068 - metric_choose_argument_global_y_train: 0.5368
# Epoch 8: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9068 - metric_choose_argument_global_y_train: 0.5365 - val_loss: -0.8665 - val_metric_choose_argument_global_y_train: 0.2520
# Epoch 9/50
# 4064/4065 [============================>.] - ETA: 0s - loss: -0.9122 - metric_choose_argument_global_y_train: 0.6198
# Epoch 9: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9122 - metric_choose_argument_global_y_train: 0.6197 - val_loss: -0.8666 - val_metric_choose_argument_global_y_train: 0.2670
# Epoch 10/50
# 4056/4065 [============================>.] - ETA: 0s - loss: -0.9165 - metric_choose_argument_global_y_train: 0.6898
# Epoch 10: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9165 - metric_choose_argument_global_y_train: 0.6895 - val_loss: -0.8681 - val_metric_choose_argument_global_y_train: 0.2969
# Epoch 11/50
# 4059/4065 [============================>.] - ETA: 0s - loss: -0.9204 - metric_choose_argument_global_y_train: 0.7374
# Epoch 11: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9203 - metric_choose_argument_global_y_train: 0.7368 - val_loss: -0.8681 - val_metric_choose_argument_global_y_train: 0.3233
# Epoch 12/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.9238 - metric_choose_argument_global_y_train: 0.7833
# Epoch 12: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9238 - metric_choose_argument_global_y_train: 0.7830 - val_loss: -0.8687 - val_metric_choose_argument_global_y_train: 0.3455
# Epoch 13/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9265 - metric_choose_argument_global_y_train: 0.8159
# Epoch 13: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9265 - metric_choose_argument_global_y_train: 0.8155 - val_loss: -0.8688 - val_metric_choose_argument_global_y_train: 0.3369
# Epoch 14/50
# 4053/4065 [============================>.] - ETA: 0s - loss: -0.9292 - metric_choose_argument_global_y_train: 0.8428
# Epoch 14: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9292 - metric_choose_argument_global_y_train: 0.8431 - val_loss: -0.8679 - val_metric_choose_argument_global_y_train: 0.3547
# Epoch 15/50
# 4062/4065 [============================>.] - ETA: 0s - loss: -0.9316 - metric_choose_argument_global_y_train: 0.8688
# Epoch 15: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9316 - metric_choose_argument_global_y_train: 0.8686 - val_loss: -0.8693 - val_metric_choose_argument_global_y_train: 0.3762
# Epoch 16/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9336 - metric_choose_argument_global_y_train: 0.8833
# Epoch 16: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9336 - metric_choose_argument_global_y_train: 0.8834 - val_loss: -0.8679 - val_metric_choose_argument_global_y_train: 0.3690
# Epoch 17/50
# 4053/4065 [============================>.] - ETA: 0s - loss: -0.9355 - metric_choose_argument_global_y_train: 0.9057
# Epoch 17: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9354 - metric_choose_argument_global_y_train: 0.9058 - val_loss: -0.8687 - val_metric_choose_argument_global_y_train: 0.3683
# Epoch 18/50
# 4062/4065 [============================>.] - ETA: 0s - loss: -0.9370 - metric_choose_argument_global_y_train: 0.9129
# Epoch 18: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9370 - metric_choose_argument_global_y_train: 0.9129 - val_loss: -0.8684 - val_metric_choose_argument_global_y_train: 0.3890
# Epoch 19/50
# 4064/4065 [============================>.] - ETA: 0s - loss: -0.9386 - metric_choose_argument_global_y_train: 0.9279
# Epoch 19: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9386 - metric_choose_argument_global_y_train: 0.9279 - val_loss: -0.8700 - val_metric_choose_argument_global_y_train: 0.3769
# Epoch 20/50
# 4050/4065 [============================>.] - ETA: 0s - loss: -0.9400 - metric_choose_argument_global_y_train: 0.9304
# Epoch 20: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9399 - metric_choose_argument_global_y_train: 0.9304 - val_loss: -0.8697 - val_metric_choose_argument_global_y_train: 0.3862
# Epoch 21/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9412 - metric_choose_argument_global_y_train: 0.9388
# Epoch 21: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9412 - metric_choose_argument_global_y_train: 0.9390 - val_loss: -0.8700 - val_metric_choose_argument_global_y_train: 0.3883
# Epoch 22/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.9424 - metric_choose_argument_global_y_train: 0.9430
# Epoch 22: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9424 - metric_choose_argument_global_y_train: 0.9429 - val_loss: -0.8689 - val_metric_choose_argument_global_y_train: 0.3926
# Epoch 23/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9435 - metric_choose_argument_global_y_train: 0.9514
# Epoch 23: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9434 - metric_choose_argument_global_y_train: 0.9513 - val_loss: -0.8698 - val_metric_choose_argument_global_y_train: 0.3847
# Epoch 24/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9445 - metric_choose_argument_global_y_train: 0.9479
# Epoch 24: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9445 - metric_choose_argument_global_y_train: 0.9478 - val_loss: -0.8682 - val_metric_choose_argument_global_y_train: 0.3997
# Epoch 25/50
# 4057/4065 [============================>.] - ETA: 0s - loss: -0.9454 - metric_choose_argument_global_y_train: 0.9522
# Epoch 25: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9454 - metric_choose_argument_global_y_train: 0.9523 - val_loss: -0.8692 - val_metric_choose_argument_global_y_train: 0.4004
# Epoch 26/50
# 4050/4065 [============================>.] - ETA: 0s - loss: -0.9462 - metric_choose_argument_global_y_train: 0.9543
# Epoch 26: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9462 - metric_choose_argument_global_y_train: 0.9545 - val_loss: -0.8687 - val_metric_choose_argument_global_y_train: 0.3997
# Epoch 27/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.9471 - metric_choose_argument_global_y_train: 0.9588
# Epoch 27: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9471 - metric_choose_argument_global_y_train: 0.9587 - val_loss: -0.8688 - val_metric_choose_argument_global_y_train: 0.3990
# Epoch 28/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.9478 - metric_choose_argument_global_y_train: 0.9605
# Epoch 28: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9478 - metric_choose_argument_global_y_train: 0.9606 - val_loss: -0.8692 - val_metric_choose_argument_global_y_train: 0.3911
# Epoch 29/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.9485 - metric_choose_argument_global_y_train: 0.9590
# Epoch 29: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9485 - metric_choose_argument_global_y_train: 0.9592 - val_loss: -0.8695 - val_metric_choose_argument_global_y_train: 0.3890
# Epoch 30/50
# 4058/4065 [============================>.] - ETA: 0s - loss: -0.9492 - metric_choose_argument_global_y_train: 0.9645
# Epoch 30: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9492 - metric_choose_argument_global_y_train: 0.9643 - val_loss: -0.8685 - val_metric_choose_argument_global_y_train: 0.3997
# Epoch 31/50
# 4053/4065 [============================>.] - ETA: 0s - loss: -0.9498 - metric_choose_argument_global_y_train: 0.9645
# Epoch 31: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9498 - metric_choose_argument_global_y_train: 0.9643 - val_loss: -0.8692 - val_metric_choose_argument_global_y_train: 0.4118
# Epoch 32/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9505 - metric_choose_argument_global_y_train: 0.9642
# Epoch 32: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9504 - metric_choose_argument_global_y_train: 0.9643 - val_loss: -0.8691 - val_metric_choose_argument_global_y_train: 0.3997
# Epoch 33/50
# 4059/4065 [============================>.] - ETA: 0s - loss: -0.9510 - metric_choose_argument_global_y_train: 0.9675
# Epoch 33: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9510 - metric_choose_argument_global_y_train: 0.9675 - val_loss: -0.8695 - val_metric_choose_argument_global_y_train: 0.4090
# Epoch 34/50
# 4064/4065 [============================>.] - ETA: 0s - loss: -0.9516 - metric_choose_argument_global_y_train: 0.9653
# Epoch 34: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9516 - metric_choose_argument_global_y_train: 0.9653 - val_loss: -0.8686 - val_metric_choose_argument_global_y_train: 0.3926
# Epoch 35/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9521 - metric_choose_argument_global_y_train: 0.9660
# Epoch 35: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9521 - metric_choose_argument_global_y_train: 0.9661 - val_loss: -0.8682 - val_metric_choose_argument_global_y_train: 0.4026
# Epoch 36/50
# 4064/4065 [============================>.] - ETA: 0s - loss: -0.9525 - metric_choose_argument_global_y_train: 0.9685
# Epoch 36: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9525 - metric_choose_argument_global_y_train: 0.9685 - val_loss: -0.8686 - val_metric_choose_argument_global_y_train: 0.4047
# Epoch 37/50
# 4050/4065 [============================>.] - ETA: 0s - loss: -0.9531 - metric_choose_argument_global_y_train: 0.9672
# Epoch 37: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9531 - metric_choose_argument_global_y_train: 0.9673 - val_loss: -0.8685 - val_metric_choose_argument_global_y_train: 0.4040
# Epoch 38/50
# 4050/4065 [============================>.] - ETA: 0s - loss: -0.9535 - metric_choose_argument_global_y_train: 0.9669
# Epoch 38: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9535 - metric_choose_argument_global_y_train: 0.9670 - val_loss: -0.8678 - val_metric_choose_argument_global_y_train: 0.4047
# Epoch 39/50
# 4051/4065 [============================>.] - ETA: 0s - loss: -0.9539 - metric_choose_argument_global_y_train: 0.9677
# Epoch 39: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9539 - metric_choose_argument_global_y_train: 0.9678 - val_loss: -0.8682 - val_metric_choose_argument_global_y_train: 0.4090
# Epoch 40/50
# 4054/4065 [============================>.] - ETA: 0s - loss: -0.9543 - metric_choose_argument_global_y_train: 0.9667
# Epoch 40: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9543 - metric_choose_argument_global_y_train: 0.9668 - val_loss: -0.8680 - val_metric_choose_argument_global_y_train: 0.4054
# Epoch 41/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9548 - metric_choose_argument_global_y_train: 0.9692
# Epoch 41: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9547 - metric_choose_argument_global_y_train: 0.9690 - val_loss: -0.8680 - val_metric_choose_argument_global_y_train: 0.4019
# Epoch 42/50
# 4050/4065 [============================>.] - ETA: 0s - loss: -0.9551 - metric_choose_argument_global_y_train: 0.9699
# Epoch 42: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9552 - metric_choose_argument_global_y_train: 0.9697 - val_loss: -0.8680 - val_metric_choose_argument_global_y_train: 0.4083
# Epoch 43/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9555 - metric_choose_argument_global_y_train: 0.9692
# Epoch 43: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9555 - metric_choose_argument_global_y_train: 0.9690 - val_loss: -0.8676 - val_metric_choose_argument_global_y_train: 0.3961
# Epoch 44/50
# 4065/4065 [==============================] - ETA: 0s - loss: -0.9559 - metric_choose_argument_global_y_train: 0.9673
# Epoch 44: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9559 - metric_choose_argument_global_y_train: 0.9673 - val_loss: -0.8679 - val_metric_choose_argument_global_y_train: 0.4126
# Epoch 45/50
# 4064/4065 [============================>.] - ETA: 0s - loss: -0.9562 - metric_choose_argument_global_y_train: 0.9683
# Epoch 45: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9562 - metric_choose_argument_global_y_train: 0.9683 - val_loss: -0.8675 - val_metric_choose_argument_global_y_train: 0.4090
# Epoch 46/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9566 - metric_choose_argument_global_y_train: 0.9665
# Epoch 46: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9566 - metric_choose_argument_global_y_train: 0.9665 - val_loss: -0.8674 - val_metric_choose_argument_global_y_train: 0.4090
# Epoch 47/50
# 4065/4065 [==============================] - ETA: 0s - loss: -0.9569 - metric_choose_argument_global_y_train: 0.9680
# Epoch 47: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9569 - metric_choose_argument_global_y_train: 0.9680 - val_loss: -0.8674 - val_metric_choose_argument_global_y_train: 0.4054
# Epoch 48/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9572 - metric_choose_argument_global_y_train: 0.9702
# Epoch 48: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 17s 4ms/step - loss: -0.9572 - metric_choose_argument_global_y_train: 0.9702 - val_loss: -0.8673 - val_metric_choose_argument_global_y_train: 0.4090
# Epoch 49/50
# 4065/4065 [==============================] - ETA: 0s - loss: -0.9575 - metric_choose_argument_global_y_train: 0.9732
# Epoch 49: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9575 - metric_choose_argument_global_y_train: 0.9732 - val_loss: -0.8672 - val_metric_choose_argument_global_y_train: 0.4011
# Epoch 50/50
# 4052/4065 [============================>.] - ETA: 0s - loss: -0.9578 - metric_choose_argument_global_y_train: 0.9696
# Epoch 50: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 16s 4ms/step - loss: -0.9578 - metric_choose_argument_global_y_train: 0.9697 - val_loss: -0.8667 - val_metric_choose_argument_global_y_train: 0.3997

# %%
global_history_df_2_layer = pd.DataFrame(global_history_2_layer.history)

# %%
output_folder_path = 'current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/'
os.makedirs(output_folder_path, exist_ok=True)
global_history_df_2_layer.to_csv(f'{output_folder_path}global_training_log.csv')
global_autoencoder_model_2_layer.save(f'{output_folder_path}global_autoencoder_model.keras')

# %% [markdown]
# ## 3-layer model

# %% [markdown]
# ### 3-layer architecture

# %%
# Layers
input_layer = tf.keras.layers.Input(shape=(768, ), name="Input")
hidden_layer_1 = tf.keras.layers.Dense(units=768*4, activation="relu", name="Hidden1")(input_layer)
hidden_layer_2 = tf.keras.layers.Dense(units=768*2, activation="relu", name="Hidden2")(hidden_layer_1)
hidden_layer_3 = tf.keras.layers.Dense(units=768, activation="relu", name="Hidden3")(hidden_layer_2)
output_layer = tf.keras.layers.Dense(units=768, activation="linear", name="Output")(hidden_layer_3)

# %%
# Model
autoencoder_model_3_layer = tf.keras.Model(inputs=input_layer, outputs=output_layer)
autoencoder_model_3_layer.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 768)]             0
#
#  Hidden1 (Dense)             (None, 3072)              2362368
#
#  Hidden2 (Dense)             (None, 1536)              4720128
#
#  Hidden3 (Dense)             (None, 768)               1180416
#
#  Output (Dense)              (None, 768)               590592
#
# =================================================================
# Total params: 8853504 (33.77 MB)
# Trainable params: 8853504 (33.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Global Training

# %%
# Global Model
global_autoencoder_model_3_layer = autoencoder_model_3_layer
global_autoencoder_model_3_layer.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
  loss="cosine_similarity",
  metrics=[metric_choose_argument_global_y_train]
)

# %%
checkpoint_callback = ModelCheckpoint(filepath='global_autoencoder_weights.keras', save_best_only=False, save_weights_only=False, verbose=1)
csv_logger_callback = CSVLogger(filename='global_training_log.csv', separator=',', append=True)
global_history_3_layer = global_autoencoder_model_3_layer.fit(
  x=x_train,
  y=y_train,
  batch_size=1,
  epochs=50,
  validation_data = (x_test, y_test),
  callbacks=[checkpoint_callback, csv_logger_callback]
)
# Out:
# Epoch 1/50
# 4055/4065 [============================>.] - ETA: 0s - loss: -0.8005 - metric_choose_argument_global_y_train: 0.0015
# Epoch 1: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 31s 6ms/step - loss: -0.8005 - metric_choose_argument_global_y_train: 0.0015 - val_loss: -0.8147 - val_metric_choose_argument_global_y_train: 0.0043
# Epoch 2/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.8278 - metric_choose_argument_global_y_train: 0.0138
# Epoch 2: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8278 - metric_choose_argument_global_y_train: 0.0138 - val_loss: -0.8288 - val_metric_choose_argument_global_y_train: 0.0150
# Epoch 3/50
# 4062/4065 [============================>.] - ETA: 0s - loss: -0.8429 - metric_choose_argument_global_y_train: 0.0352
# Epoch 3: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8429 - metric_choose_argument_global_y_train: 0.0352 - val_loss: -0.8382 - val_metric_choose_argument_global_y_train: 0.0278
# Epoch 4/50
# 4064/4065 [============================>.] - ETA: 0s - loss: -0.8543 - metric_choose_argument_global_y_train: 0.0605
# Epoch 4: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8543 - metric_choose_argument_global_y_train: 0.0605 - val_loss: -0.8425 - val_metric_choose_argument_global_y_train: 0.0385
# Epoch 5/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.8632 - metric_choose_argument_global_y_train: 0.0894
# Epoch 5: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8632 - metric_choose_argument_global_y_train: 0.0893 - val_loss: -0.8452 - val_metric_choose_argument_global_y_train: 0.0642
# Epoch 6/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.8708 - metric_choose_argument_global_y_train: 0.1379
# Epoch 6: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8708 - metric_choose_argument_global_y_train: 0.1378 - val_loss: -0.8498 - val_metric_choose_argument_global_y_train: 0.0707
# Epoch 7/50
# 4065/4065 [==============================] - ETA: 0s - loss: -0.8774 - metric_choose_argument_global_y_train: 0.1781
# Epoch 7: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8774 - metric_choose_argument_global_y_train: 0.1781 - val_loss: -0.8528 - val_metric_choose_argument_global_y_train: 0.0906
# Epoch 8/50
# 4058/4065 [============================>.] - ETA: 0s - loss: -0.8835 - metric_choose_argument_global_y_train: 0.2390
# Epoch 8: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8835 - metric_choose_argument_global_y_train: 0.2391 - val_loss: -0.8549 - val_metric_choose_argument_global_y_train: 0.1042
# Epoch 9/50
# 4058/4065 [============================>.] - ETA: 0s - loss: -0.8890 - metric_choose_argument_global_y_train: 0.2989
# Epoch 9: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8889 - metric_choose_argument_global_y_train: 0.2989 - val_loss: -0.8566 - val_metric_choose_argument_global_y_train: 0.1406
# Epoch 10/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.8942 - metric_choose_argument_global_y_train: 0.3672
# Epoch 10: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8942 - metric_choose_argument_global_y_train: 0.3673 - val_loss: -0.8583 - val_metric_choose_argument_global_y_train: 0.1649
# Epoch 11/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.8987 - metric_choose_argument_global_y_train: 0.4304
# Epoch 11: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.8987 - metric_choose_argument_global_y_train: 0.4300 - val_loss: -0.8597 - val_metric_choose_argument_global_y_train: 0.1963
# Epoch 12/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9030 - metric_choose_argument_global_y_train: 0.4910
# Epoch 12: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9030 - metric_choose_argument_global_y_train: 0.4910 - val_loss: -0.8604 - val_metric_choose_argument_global_y_train: 0.2184
# Epoch 13/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9070 - metric_choose_argument_global_y_train: 0.5607
# Epoch 13: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9070 - metric_choose_argument_global_y_train: 0.5604 - val_loss: -0.8615 - val_metric_choose_argument_global_y_train: 0.2355
# Epoch 14/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9107 - metric_choose_argument_global_y_train: 0.6181
# Epoch 14: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9106 - metric_choose_argument_global_y_train: 0.6177 - val_loss: -0.8629 - val_metric_choose_argument_global_y_train: 0.2734
# Epoch 15/50
# 4055/4065 [============================>.] - ETA: 0s - loss: -0.9140 - metric_choose_argument_global_y_train: 0.6641
# Epoch 15: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9140 - metric_choose_argument_global_y_train: 0.6645 - val_loss: -0.8634 - val_metric_choose_argument_global_y_train: 0.2734
# Epoch 16/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9171 - metric_choose_argument_global_y_train: 0.7152
# Epoch 16: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9171 - metric_choose_argument_global_y_train: 0.7154 - val_loss: -0.8627 - val_metric_choose_argument_global_y_train: 0.3026
# Epoch 17/50
# 4056/4065 [============================>.] - ETA: 0s - loss: -0.9196 - metric_choose_argument_global_y_train: 0.7544
# Epoch 17: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9196 - metric_choose_argument_global_y_train: 0.7547 - val_loss: -0.8637 - val_metric_choose_argument_global_y_train: 0.3112
# Epoch 18/50
# 4062/4065 [============================>.] - ETA: 0s - loss: -0.9223 - metric_choose_argument_global_y_train: 0.7861
# Epoch 18: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9223 - metric_choose_argument_global_y_train: 0.7862 - val_loss: -0.8646 - val_metric_choose_argument_global_y_train: 0.3291
# Epoch 19/50
# 4056/4065 [============================>.] - ETA: 0s - loss: -0.9245 - metric_choose_argument_global_y_train: 0.8203
# Epoch 19: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9245 - metric_choose_argument_global_y_train: 0.8199 - val_loss: -0.8641 - val_metric_choose_argument_global_y_train: 0.3512
# Epoch 20/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9267 - metric_choose_argument_global_y_train: 0.8470
# Epoch 20: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9267 - metric_choose_argument_global_y_train: 0.8472 - val_loss: -0.8652 - val_metric_choose_argument_global_y_train: 0.3426
# Epoch 21/50
# 4062/4065 [============================>.] - ETA: 0s - loss: -0.9285 - metric_choose_argument_global_y_train: 0.8587
# Epoch 21: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9285 - metric_choose_argument_global_y_train: 0.8588 - val_loss: -0.8657 - val_metric_choose_argument_global_y_train: 0.3576
# Epoch 22/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9303 - metric_choose_argument_global_y_train: 0.8787
# Epoch 22: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9303 - metric_choose_argument_global_y_train: 0.8785 - val_loss: -0.8666 - val_metric_choose_argument_global_y_train: 0.3690
# Epoch 23/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9319 - metric_choose_argument_global_y_train: 0.8953
# Epoch 23: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9319 - metric_choose_argument_global_y_train: 0.8952 - val_loss: -0.8669 - val_metric_choose_argument_global_y_train: 0.3690
# Epoch 24/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9335 - metric_choose_argument_global_y_train: 0.9079
# Epoch 24: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9335 - metric_choose_argument_global_y_train: 0.9077 - val_loss: -0.8667 - val_metric_choose_argument_global_y_train: 0.3697
# Epoch 25/50
# 4059/4065 [============================>.] - ETA: 0s - loss: -0.9349 - metric_choose_argument_global_y_train: 0.9133
# Epoch 25: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9348 - metric_choose_argument_global_y_train: 0.9134 - val_loss: -0.8672 - val_metric_choose_argument_global_y_train: 0.3762
# Epoch 26/50
# 4055/4065 [============================>.] - ETA: 0s - loss: -0.9362 - metric_choose_argument_global_y_train: 0.9238
# Epoch 26: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9363 - metric_choose_argument_global_y_train: 0.9237 - val_loss: -0.8667 - val_metric_choose_argument_global_y_train: 0.3762
# Epoch 27/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9374 - metric_choose_argument_global_y_train: 0.9313
# Epoch 27: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9374 - metric_choose_argument_global_y_train: 0.9314 - val_loss: -0.8673 - val_metric_choose_argument_global_y_train: 0.3869
# Epoch 28/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9386 - metric_choose_argument_global_y_train: 0.9352
# Epoch 28: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9386 - metric_choose_argument_global_y_train: 0.9351 - val_loss: -0.8676 - val_metric_choose_argument_global_y_train: 0.3869
# Epoch 29/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9397 - metric_choose_argument_global_y_train: 0.9355
# Epoch 29: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9397 - metric_choose_argument_global_y_train: 0.9353 - val_loss: -0.8679 - val_metric_choose_argument_global_y_train: 0.3890
# Epoch 30/50
# 4056/4065 [============================>.] - ETA: 0s - loss: -0.9407 - metric_choose_argument_global_y_train: 0.9458
# Epoch 30: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9407 - metric_choose_argument_global_y_train: 0.9456 - val_loss: -0.8676 - val_metric_choose_argument_global_y_train: 0.3897
# Epoch 31/50
# 4059/4065 [============================>.] - ETA: 0s - loss: -0.9416 - metric_choose_argument_global_y_train: 0.9473
# Epoch 31: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9416 - metric_choose_argument_global_y_train: 0.9474 - val_loss: -0.8678 - val_metric_choose_argument_global_y_train: 0.4004
# Epoch 32/50
# 4058/4065 [============================>.] - ETA: 0s - loss: -0.9425 - metric_choose_argument_global_y_train: 0.9527
# Epoch 32: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9425 - metric_choose_argument_global_y_train: 0.9525 - val_loss: -0.8682 - val_metric_choose_argument_global_y_train: 0.3911
# Epoch 33/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9434 - metric_choose_argument_global_y_train: 0.9493
# Epoch 33: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9434 - metric_choose_argument_global_y_train: 0.9493 - val_loss: -0.8677 - val_metric_choose_argument_global_y_train: 0.3961
# Epoch 34/50
# 4058/4065 [============================>.] - ETA: 0s - loss: -0.9441 - metric_choose_argument_global_y_train: 0.9556
# Epoch 34: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9441 - metric_choose_argument_global_y_train: 0.9552 - val_loss: -0.8686 - val_metric_choose_argument_global_y_train: 0.3919
# Epoch 35/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9449 - metric_choose_argument_global_y_train: 0.9542
# Epoch 35: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9449 - metric_choose_argument_global_y_train: 0.9542 - val_loss: -0.8680 - val_metric_choose_argument_global_y_train: 0.3961
# Epoch 36/50
# 4055/4065 [============================>.] - ETA: 0s - loss: -0.9455 - metric_choose_argument_global_y_train: 0.9600
# Epoch 36: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9455 - metric_choose_argument_global_y_train: 0.9599 - val_loss: -0.8681 - val_metric_choose_argument_global_y_train: 0.3976
# Epoch 37/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9464 - metric_choose_argument_global_y_train: 0.9623
# Epoch 37: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9463 - metric_choose_argument_global_y_train: 0.9624 - val_loss: -0.8688 - val_metric_choose_argument_global_y_train: 0.3947
# Epoch 38/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9470 - metric_choose_argument_global_y_train: 0.9628
# Epoch 38: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9470 - metric_choose_argument_global_y_train: 0.9629 - val_loss: -0.8688 - val_metric_choose_argument_global_y_train: 0.3947
# Epoch 39/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9476 - metric_choose_argument_global_y_train: 0.9638
# Epoch 39: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9476 - metric_choose_argument_global_y_train: 0.9638 - val_loss: -0.8692 - val_metric_choose_argument_global_y_train: 0.3961
# Epoch 40/50
# 4057/4065 [============================>.] - ETA: 0s - loss: -0.9482 - metric_choose_argument_global_y_train: 0.9596
# Epoch 40: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9482 - metric_choose_argument_global_y_train: 0.9592 - val_loss: -0.8696 - val_metric_choose_argument_global_y_train: 0.3904
# Epoch 41/50
# 4059/4065 [============================>.] - ETA: 0s - loss: -0.9488 - metric_choose_argument_global_y_train: 0.9643
# Epoch 41: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9488 - metric_choose_argument_global_y_train: 0.9643 - val_loss: -0.8693 - val_metric_choose_argument_global_y_train: 0.3997
# Epoch 42/50
# 4057/4065 [============================>.] - ETA: 0s - loss: -0.9494 - metric_choose_argument_global_y_train: 0.9672
# Epoch 42: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9494 - metric_choose_argument_global_y_train: 0.9673 - val_loss: -0.8697 - val_metric_choose_argument_global_y_train: 0.3940
# Epoch 43/50
# 4060/4065 [============================>.] - ETA: 0s - loss: -0.9499 - metric_choose_argument_global_y_train: 0.9658
# Epoch 43: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9499 - metric_choose_argument_global_y_train: 0.9658 - val_loss: -0.8694 - val_metric_choose_argument_global_y_train: 0.3862
# Epoch 44/50
# 4058/4065 [============================>.] - ETA: 0s - loss: -0.9505 - metric_choose_argument_global_y_train: 0.9653
# Epoch 44: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9505 - metric_choose_argument_global_y_train: 0.9653 - val_loss: -0.8695 - val_metric_choose_argument_global_y_train: 0.3961
# Epoch 45/50
# 4059/4065 [============================>.] - ETA: 0s - loss: -0.9509 - metric_choose_argument_global_y_train: 0.9682
# Epoch 45: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9509 - metric_choose_argument_global_y_train: 0.9683 - val_loss: -0.8699 - val_metric_choose_argument_global_y_train: 0.3933
# Epoch 46/50
# 4056/4065 [============================>.] - ETA: 0s - loss: -0.9515 - metric_choose_argument_global_y_train: 0.9670
# Epoch 46: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9514 - metric_choose_argument_global_y_train: 0.9670 - val_loss: -0.8700 - val_metric_choose_argument_global_y_train: 0.3997
# Epoch 47/50
# 4061/4065 [============================>.] - ETA: 0s - loss: -0.9519 - metric_choose_argument_global_y_train: 0.9672
# Epoch 47: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9520 - metric_choose_argument_global_y_train: 0.9673 - val_loss: -0.8701 - val_metric_choose_argument_global_y_train: 0.4011
# Epoch 48/50
# 4057/4065 [============================>.] - ETA: 0s - loss: -0.9524 - metric_choose_argument_global_y_train: 0.9684
# Epoch 48: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9524 - metric_choose_argument_global_y_train: 0.9680 - val_loss: -0.8701 - val_metric_choose_argument_global_y_train: 0.3976
# Epoch 49/50
# 4063/4065 [============================>.] - ETA: 0s - loss: -0.9529 - metric_choose_argument_global_y_train: 0.9658
# Epoch 49: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9529 - metric_choose_argument_global_y_train: 0.9658 - val_loss: -0.8701 - val_metric_choose_argument_global_y_train: 0.4011
# Epoch 50/50
# 4057/4065 [============================>.] - ETA: 0s - loss: -0.9533 - metric_choose_argument_global_y_train: 0.9677
# Epoch 50: saving model to global_autoencoder_weights.keras
# 4065/4065 [==============================] - 23s 6ms/step - loss: -0.9533 - metric_choose_argument_global_y_train: 0.9678 - val_loss: -0.8700 - val_metric_choose_argument_global_y_train: 0.3990

# %%
global_history_df_3_layer = pd.DataFrame(global_history_3_layer.history)

# %%
output_folder_path = 'current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/'
os.makedirs(output_folder_path, exist_ok=True)
global_history_df_3_layer.to_csv(f'{output_folder_path}global_training_log.csv')
global_autoencoder_model_3_layer.save(f'{output_folder_path}global_autoencoder_model.keras')

# %% [markdown]
# ## Plot training history

# %% [markdown]
# ### 1-layer architecture training history

# %%
# Access training history
global_history_1_layer = pd.DataFrame(pd.read_csv('current-data-dump/nomic-autoencoder/nomic_sd_training_log.csv'))
global_history_1_layer = pd.melt(global_history_1_layer, id_vars='epoch', value_vars=['metric_choose_argument_global_sd_y_train', 'val_metric_choose_argument_global_sd_y_train'], var_name='dataset', value_name='accuracy')
global_history_1_layer = global_history_1_layer.replace(['metric_choose_argument_global_sd_y_train', 'val_metric_choose_argument_global_sd_y_train'], ['training set', 'validation set'])
global_history_1_layer['layers'] = '1'

# %% [markdown]
# ### 2-layer architecture training history

# %%
# Access training history
global_history_2_layer = pd.DataFrame(pd.read_csv('current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/global_training_log.csv'))
global_history_2_layer = pd.melt(global_history_2_layer, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], var_name='dataset', value_name='accuracy')
global_history_2_layer = global_history_2_layer.replace(['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], ['training set', 'validation set'])
global_history_2_layer.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
global_history_2_layer['layers'] = '2'

# %%
global_training_plot_2_layer = ggplot(global_history_2_layer, aes(x='epoch', y='accuracy', linetype='dataset')) + geom_line() + labs(title='Learning Curve of Model Trained on Unshuffled Data', x='Epoch', y='Accuracy')
ggsave(global_training_plot_2_layer, "current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/global_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/nomic-autoencoder/other-architectures/2-layer-architecture/global_training_plot.png

# %% [markdown]
# ### 3-layer architecture training history

# %%
# Access training history
global_history_3_layer = pd.DataFrame(pd.read_csv("current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/global_training_log.csv"))
global_history_3_layer = pd.melt(global_history_3_layer, id_vars='Unnamed: 0', value_vars=['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], var_name='dataset', value_name='accuracy')
global_history_3_layer = global_history_3_layer.replace(['metric_choose_argument_global_y_train', 'val_metric_choose_argument_global_y_train'], ['training set', 'validation set'])
global_history_3_layer.rename(columns = {'Unnamed: 0':'epoch'}, inplace = True)
global_history_3_layer['layers'] = '3'

# %%
global_training_plot_3_layer = ggplot(global_history_3_layer, aes(x='epoch', y='accuracy', linetype='dataset')) + geom_line() + labs(title='Learning Curve of Model Trained on Shuffled Data', x='Epoch', y='Accuracy')
ggsave(global_training_plot_3_layer, "current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/global_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/nomic-autoencoder/other-architectures/3-layer-architecture/global_training_plot.png

# %% [markdown]
# ## Combined Training Plots

# %%
combined_global_training_df = pd.concat([global_history_1_layer, global_history_2_layer, global_history_3_layer])

# %%
color_map = {'1': '#AAAAAA', '2': '#777777', '3': 'black'}
linetype_map = {'validation set': 'solid', 'training set': 'dashed'}

combined_global_plot = (
  ggplot(combined_global_training_df, aes(x='epoch', y='accuracy', linetype='dataset', color='layers')) +
  geom_line(size=2) +
  labs(title='Learning Curves of 1-Layer vs 2-Layer vs 3-Layer Networks (ArguAna; Nomic)', x='Epoch', y='Accuracy') +
  scale_color_manual(color_map) +
  scale_linetype_manual(linetype_map) +
  theme(
    figure_size=(16,24),
    axis_title=element_text(size=40),
    axis_text=element_text(size=32),
    legend_title=element_text(size=40, lineheight=1.5),
    legend_text=element_text(size=32, lineheight=1.5),
    plot_title=element_text(size=48, wrap=True, lineheight=1.5),
    legend_position="bottom",
    legend_key_width=64
  ) +
  guides(fill = guide_legend(byrow = True))
)
ggsave(combined_global_plot, "current-data-dump/nomic-autoencoder/other-architectures/combined_global_training_plot.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:587: PlotnineWarning: Saving 16 x 24 in image.
# /usr/local/lib/python3.10/dist-packages/plotnine/ggplot.py:588: PlotnineWarning: Filename: current-data-dump/nomic-autoencoder/other-architectures/combined_global_training_plot.png

# %%
combined_global_plot
# Out:
# <Figure Size: (1600 x 2400)>

# %% [markdown]
# ## Final Export

# %%
other_architectures_file_path = 'current-data-dump/nomic-autoencoder/other-architectures/'
other_architectures_file_path_zip = 'current-data-dump/nomic-autoencoder/other-architectures/'
shutil.make_archive(other_architectures_file_path_zip, 'zip', other_architectures_file_path)
print(f"Zip file created at: {other_architectures_file_path_zip}")
result = subprocess.run([f"osf -p sakjg upload --force {other_architectures_file_path_zip}.zip data-dump/nomic-autoencoder/other_architectures.zip"], shell=True, capture_output=True, text=True)
print(result.stderr)
print(f"File: {other_architectures_file_path_zip} uploaded at osfstorage")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.10/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1775             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1776                 shutil.copyfileobj(src, dest, 1024*8)
#    1777
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
#     197             break
# --> 198         fdst_write(buf)
#     199
#
# /usr/lib/python3.10/zipfile.py in write(self, data)
#    1138         if self._compressor:
# -> 1139             data = self._compressor.compress(data)
#    1140             self._compress_size += len(data)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-55-2c3a0783a7ad> in <cell line: 3>()
#       1 other_architectures_file_path = 'current-data-dump/nomic-autoencoder/other-architectures/'
#       2 other_architectures_file_path_zip = 'current-data-dump/nomic-autoencoder/other-architectures/'
# ----> 3 shutil.make_archive(other_architectures_file_path_zip, 'zip', other_architectures_file_path)
#       4 print(f"Zip file created at: {other_architectures_file_path_zip}")
#       5 result = subprocess.run([f"osf -p sakjg upload --force {other_architectures_file_path_zip}.zip data-dump/nomic-autoencoder/other_architectures.zip"], shell=True, capture_output=True, text=True)
#
# /usr/lib/python3.10/shutil.py in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1122
#    1123     try:
# -> 1124         filename = func(base_name, base_dir, **kwargs)
#    1125     finally:
#    1126         if save_cwd is not None:
#
# /usr/lib/python3.10/shutil.py in _make_zipfile(base_name, base_dir, verbose, dry_run, logger, owner, group, root_dir)
#    1007                     if os.path.isfile(path):
#    1008                         arcname = os.path.join(arcdirpath, name)
# -> 1009                         zf.write(path, arcname)
#    1010                         if logger is not None:
#    1011                             logger.info("adding '%s'", path)
#
# /usr/lib/python3.10/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1773                 self.start_dir = self.fp.tell()
#    1774         else:
# -> 1775             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
#    1776                 shutil.copyfileobj(src, dest, 1024*8)
#    1777
#
# /usr/lib/python3.10/zipfile.py in close(self)
#    1168                 if not self._zip64:
#    1169                     if self._file_size > ZIP64_LIMIT:
# -> 1170                         raise RuntimeError(
#    1171                             'File size unexpectedly exceeded ZIP64 limit')
#    1172                     if self._compress_size > ZIP64_LIMIT:
#
# RuntimeError: File size unexpectedly exceeded ZIP64 limit

# %% [markdown]
# ## Import data

# %%
subprocess.run("osf -p sakjg fetch --force osfstorage/data-dump/nomic-autoencoder/other_architectures.zip", shell=True)
print("other_architectures.zip successfully imported")
nomic_autoencoder_file_path_zip = 'other_architectures.zip'
nomic_autoencoder_file_path = 'current-data-dump/nomic-autoencoder/other-architectures'
os.makedirs(nomic_autoencoder_file_path, exist_ok=True)
with zipfile.ZipFile(nomic_autoencoder_file_path_zip, 'r') as zip_ref:
  zip_ref.extractall(nomic_autoencoder_file_path)
extracted_files = os.listdir(nomic_autoencoder_file_path)
print("Files extracted:", extracted_files)
# Out:
# other_architectures.zip successfully imported
# Files extracted: ['3-layer-architecture', 'combined_global_training_plot.png', '.zip', '2-layer-architecture']
